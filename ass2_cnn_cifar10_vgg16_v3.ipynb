# %%
# %matplotlib inline

# %% [markdown]
# # Load CIFAR10 dataset

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainvalset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
num_classes = len(classes)

trainset, valset = torch.utils.data.random_split(trainvalset, [0.9, 0.1])

trainloader = torch.utils.data.DataLoader(trainset, batch_size=64,
                                          shuffle=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# function to show an image

def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# horse  bird   dog plane

# %% [markdown]
# # VGG16 Implementation

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models
import copy
import gc

vgg = models.vgg16_bn(weights=None)

# Prevent weight update from backprop
for param in vgg.parameters():
    param.requires_grad = False

# Change the output layer to 10 classes
final_in_features = vgg.classifier[6].in_features
vgg.classifier[6] = nn.Linear(final_in_features, num_classes)

for param in vgg.parameters():
    if param.requires_grad:
        print(param.shape)
# Out:
# torch.Size([10, 4096])
# torch.Size([10])

# %% [markdown]
# ## Train the model

# %%
batch_size = 16

trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False)
valloader = torch.utils.data.DataLoader(valset, batch_size=batch_size, shuffle=False)

def evaluation(dataloader, model):
    total, correct = 0, 0
    for data in dataloader:
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, pred = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (pred == labels).sum().item()
    return correct / total

vgg = vgg.to(device)
loss_fn = nn.CrossEntropyLoss()
opt = optim.SGD(vgg.parameters(), lr=0.001)

# %%
max_epochs = 20

n_iters = np.ceil(50000/batch_size)

min_loss = 1000

loss_epoch_arr = []
train_loss_arr = []
val_loss_arr = []
train_acc_arr = []
val_acc_arr = []

for epoch in range(max_epochs):
    train_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        opt.zero_grad()
        outputs = vgg(inputs)
        loss = loss_fn(outputs, labels)
        loss.backward()
        opt.step()
        
        train_loss += loss.item()  # Accumulate training loss

        # Update minimum loss and save best model
        if min_loss > loss.item():
            min_loss = loss.item()
            best_model = copy.deepcopy(vgg.state_dict())
            # print('Min loss %0.2f' % min_loss)
        
        # Print training progress every 100 iterations
        if i % 100 == 0:
            print('Iteration: %d/%d, Loss: %0.2f' % (i, np.ceil(50000/batch_size), loss.item()))
            
        # Clear memory
        del inputs, labels, outputs
        torch.cuda.empty_cache()
        gc.collect()
    
    # Record average training loss for the epoch
    train_loss_arr.append(train_loss / len(trainloader))
    
    # Validation loop to calculate validation loss
    val_loss = 0.0
    with torch.no_grad():
        for val_data in valloader:
            val_inputs, val_labels = val_data
            val_inputs, val_labels = val_inputs.to(device), val_labels.to(device)
            val_outputs = vgg(val_inputs)
            v_loss = loss_fn(val_outputs, val_labels)
            val_loss += v_loss.item()
    
    # Record average validation loss for the epoch
    val_loss_arr.append(val_loss / len(valloader))
    
    # Calculate training and validation accuracy
    train_acc = evaluation(trainloader, vgg)
    val_acc = evaluation(valloader, vgg)
    train_acc_arr.append(train_acc)
    val_acc_arr.append(val_acc)
    
    # Print metrics for the epoch
    print(f"Epoch [{epoch+1}/{max_epochs}], Training Loss: {train_loss_arr[-1]:.4f}, Validation Loss: {val_loss_arr[-1]:.4f}, Train Acc: {train_acc:.4f}, Val Acc: {val_acc:.4f}")
    
    # Append final loss of epoch for historical tracking
    loss_epoch_arr.append(train_loss_arr[-1])
# Out:
# Iteration: 0/3125, Loss: 23.13
# Iteration: 100/3125, Loss: 7.44
# Iteration: 200/3125, Loss: 16.18
# Iteration: 300/3125, Loss: 13.54
# Iteration: 400/3125, Loss: 13.77
# Iteration: 500/3125, Loss: 9.93
# Iteration: 600/3125, Loss: 16.17
# Iteration: 700/3125, Loss: 20.31
# Iteration: 800/3125, Loss: 15.31
# Iteration: 900/3125, Loss: 15.45
# Iteration: 1000/3125, Loss: 11.99
# Iteration: 1100/3125, Loss: 11.56
# Iteration: 1200/3125, Loss: 11.20
# Iteration: 1300/3125, Loss: 15.60
# Iteration: 1400/3125, Loss: 9.76
# Iteration: 1500/3125, Loss: 12.27
# Iteration: 1600/3125, Loss: 17.53
# Iteration: 1700/3125, Loss: 20.75
# Iteration: 1800/3125, Loss: 11.21
# Iteration: 1900/3125, Loss: 16.05
# Iteration: 2000/3125, Loss: 12.92
# Iteration: 2100/3125, Loss: 9.62
# Iteration: 2200/3125, Loss: 10.38
# Iteration: 2300/3125, Loss: 14.06
# Iteration: 2400/3125, Loss: 10.51
# Iteration: 2500/3125, Loss: 15.14
# Iteration: 2600/3125, Loss: 11.08
# Iteration: 2700/3125, Loss: 9.50
# Iteration: 2800/3125, Loss: 11.83
# Epoch [1/20], Training Loss: 13.4555, Validation Loss: 12.5442, Train Acc: 0.1578, Val Acc: 0.1584
# Iteration: 0/3125, Loss: 8.38
# Iteration: 100/3125, Loss: 14.81
# Iteration: 200/3125, Loss: 13.30
# Iteration: 300/3125, Loss: 13.03
# Iteration: 400/3125, Loss: 11.07
# Iteration: 500/3125, Loss: 11.51
# Iteration: 600/3125, Loss: 9.84
# Iteration: 700/3125, Loss: 15.67
# Iteration: 800/3125, Loss: 14.98
# Iteration: 900/3125, Loss: 12.07
# Iteration: 1000/3125, Loss: 9.26
# Iteration: 1100/3125, Loss: 12.48
# Iteration: 1200/3125, Loss: 12.33
# Iteration: 1300/3125, Loss: 12.96
# Iteration: 1400/3125, Loss: 6.98
# Iteration: 1500/3125, Loss: 5.97
# Iteration: 1600/3125, Loss: 15.36
# Iteration: 1700/3125, Loss: 6.95
# Iteration: 1800/3125, Loss: 13.26
# Iteration: 1900/3125, Loss: 11.43
# Iteration: 2000/3125, Loss: 13.54
# Iteration: 2100/3125, Loss: 12.32
# Iteration: 2200/3125, Loss: 11.70
# Iteration: 2300/3125, Loss: 8.40
# Iteration: 2400/3125, Loss: 14.54
# Iteration: 2500/3125, Loss: 11.14
# Iteration: 2600/3125, Loss: 8.39
# Iteration: 2700/3125, Loss: 10.26
# Iteration: 2800/3125, Loss: 9.13
# Epoch [2/20], Training Loss: 11.8554, Validation Loss: 11.2101, Train Acc: 0.1598, Val Acc: 0.1570
# Iteration: 0/3125, Loss: 10.78
# Iteration: 100/3125, Loss: 13.75
# Iteration: 200/3125, Loss: 8.65
# Iteration: 300/3125, Loss: 8.90
# Iteration: 400/3125, Loss: 7.05
# Iteration: 500/3125, Loss: 8.34
# Iteration: 600/3125, Loss: 13.94
# Iteration: 700/3125, Loss: 9.68
# Iteration: 800/3125, Loss: 10.78
# Iteration: 900/3125, Loss: 7.53
# Iteration: 1000/3125, Loss: 6.62
# Iteration: 1100/3125, Loss: 8.58
# Iteration: 1200/3125, Loss: 11.05
# Iteration: 1300/3125, Loss: 8.57
# Iteration: 1400/3125, Loss: 15.42
# Iteration: 1500/3125, Loss: 8.49
# Iteration: 1600/3125, Loss: 14.86
# Iteration: 1700/3125, Loss: 10.09
# Iteration: 1800/3125, Loss: 8.01
# Iteration: 1900/3125, Loss: 12.66
# Iteration: 2000/3125, Loss: 11.11
# Iteration: 2100/3125, Loss: 8.60
# Iteration: 2200/3125, Loss: 9.55
# Iteration: 2300/3125, Loss: 8.73
# Iteration: 2400/3125, Loss: 11.32
# Iteration: 2500/3125, Loss: 9.99
# Iteration: 2600/3125, Loss: 13.62
# Iteration: 2700/3125, Loss: 9.37
# Iteration: 2800/3125, Loss: 11.60
# Epoch [3/20], Training Loss: 10.4591, Validation Loss: 9.9723, Train Acc: 0.1603, Val Acc: 0.1636
# Iteration: 0/3125, Loss: 9.29
# Iteration: 100/3125, Loss: 8.89
# Iteration: 200/3125, Loss: 7.81
# Iteration: 300/3125, Loss: 10.58
# Iteration: 400/3125, Loss: 7.22
# Iteration: 500/3125, Loss: 9.75
# Iteration: 600/3125, Loss: 10.23
# Iteration: 700/3125, Loss: 9.26
# Iteration: 800/3125, Loss: 8.32
# Iteration: 900/3125, Loss: 7.56
# Iteration: 1000/3125, Loss: 8.78
# Iteration: 1100/3125, Loss: 11.69
# Iteration: 1200/3125, Loss: 7.43
# Iteration: 1300/3125, Loss: 11.20
# Iteration: 1400/3125, Loss: 10.96
# Iteration: 1500/3125, Loss: 8.10
# Iteration: 1600/3125, Loss: 10.88
# Iteration: 1700/3125, Loss: 10.81
# Iteration: 1800/3125, Loss: 9.59
# Iteration: 1900/3125, Loss: 8.23
# Iteration: 2000/3125, Loss: 10.14
# Iteration: 2100/3125, Loss: 10.41
# Iteration: 2200/3125, Loss: 5.75
# Iteration: 2300/3125, Loss: 11.52
# Iteration: 2400/3125, Loss: 7.50
# Iteration: 2500/3125, Loss: 11.27
# Iteration: 2600/3125, Loss: 7.61
# Iteration: 2700/3125, Loss: 12.03
# Iteration: 2800/3125, Loss: 6.59
# Epoch [4/20], Training Loss: 9.3388, Validation Loss: 8.6564, Train Acc: 0.1642, Val Acc: 0.1708
# Iteration: 0/3125, Loss: 7.69
# Iteration: 100/3125, Loss: 9.33
# Iteration: 200/3125, Loss: 7.70
# Iteration: 300/3125, Loss: 9.81
# Iteration: 400/3125, Loss: 6.47
# Iteration: 500/3125, Loss: 7.61
# Iteration: 600/3125, Loss: 6.19
# Iteration: 700/3125, Loss: 8.10
# Iteration: 800/3125, Loss: 7.24
# Iteration: 900/3125, Loss: 6.62
# Iteration: 1000/3125, Loss: 8.37
# Iteration: 1100/3125, Loss: 7.15
# Iteration: 1200/3125, Loss: 8.26
# Iteration: 1300/3125, Loss: 8.04
# Iteration: 1400/3125, Loss: 6.64
# Iteration: 1500/3125, Loss: 6.92
# Iteration: 1600/3125, Loss: 6.57
# Iteration: 1700/3125, Loss: 9.62
# Iteration: 1800/3125, Loss: 8.53
# Iteration: 1900/3125, Loss: 8.97
# Iteration: 2000/3125, Loss: 7.54
# Iteration: 2100/3125, Loss: 6.58
# Iteration: 2200/3125, Loss: 9.44
# Iteration: 2300/3125, Loss: 9.44
# Iteration: 2400/3125, Loss: 8.02
# Iteration: 2500/3125, Loss: 5.30
# Iteration: 2600/3125, Loss: 8.79
# Iteration: 2700/3125, Loss: 9.13
# Iteration: 2800/3125, Loss: 8.01
# Epoch [5/20], Training Loss: 8.3257, Validation Loss: 7.8335, Train Acc: 0.1652, Val Acc: 0.1720
# Iteration: 0/3125, Loss: 7.80
# Iteration: 100/3125, Loss: 5.59
# Iteration: 200/3125, Loss: 7.33
# Iteration: 300/3125, Loss: 8.26
# Iteration: 400/3125, Loss: 10.14
# Iteration: 500/3125, Loss: 8.95
# Iteration: 600/3125, Loss: 9.40
# Iteration: 700/3125, Loss: 6.06
# Iteration: 800/3125, Loss: 8.08
# Iteration: 900/3125, Loss: 9.42
# Iteration: 1000/3125, Loss: 7.25
# Iteration: 1100/3125, Loss: 7.37
# Iteration: 1200/3125, Loss: 5.33
# Iteration: 1300/3125, Loss: 5.58
# Iteration: 1400/3125, Loss: 8.20
# Iteration: 1500/3125, Loss: 7.36
# Iteration: 1600/3125, Loss: 5.85
# Iteration: 1700/3125, Loss: 8.80
# Iteration: 1800/3125, Loss: 9.07
# Iteration: 1900/3125, Loss: 7.61
# Iteration: 2000/3125, Loss: 8.17
# Iteration: 2100/3125, Loss: 7.73
# Iteration: 2200/3125, Loss: 7.17
# Iteration: 2300/3125, Loss: 7.98
# Iteration: 2400/3125, Loss: 6.07
# Iteration: 2500/3125, Loss: 4.80
# Iteration: 2600/3125, Loss: 8.53
# Iteration: 2700/3125, Loss: 7.84
# Iteration: 2800/3125, Loss: 7.37
# Epoch [6/20], Training Loss: 7.4860, Validation Loss: 6.9913, Train Acc: 0.1681, Val Acc: 0.1692
# Iteration: 0/3125, Loss: 4.97
# Iteration: 100/3125, Loss: 5.75
# Iteration: 200/3125, Loss: 6.59
# Iteration: 300/3125, Loss: 5.55
# Iteration: 400/3125, Loss: 8.00
# Iteration: 500/3125, Loss: 4.31
# Iteration: 600/3125, Loss: 5.97
# Iteration: 700/3125, Loss: 5.40
# Iteration: 800/3125, Loss: 4.37
# Iteration: 900/3125, Loss: 5.66
# Iteration: 1000/3125, Loss: 6.80
# Iteration: 1100/3125, Loss: 7.38
# Iteration: 1200/3125, Loss: 6.58
# Iteration: 1300/3125, Loss: 4.82
# Iteration: 1400/3125, Loss: 8.67
# Iteration: 1500/3125, Loss: 6.84
# Iteration: 1600/3125, Loss: 6.94
# Iteration: 1700/3125, Loss: 4.61
# Iteration: 1800/3125, Loss: 6.15
# Iteration: 1900/3125, Loss: 8.43
# Iteration: 2000/3125, Loss: 7.05
# Iteration: 2100/3125, Loss: 5.84
# Iteration: 2200/3125, Loss: 5.61
# Iteration: 2300/3125, Loss: 4.95
# Iteration: 2400/3125, Loss: 8.15
# Iteration: 2500/3125, Loss: 6.74
# Iteration: 2600/3125, Loss: 7.59
# Iteration: 2700/3125, Loss: 7.41
# Iteration: 2800/3125, Loss: 6.70
# Epoch [7/20], Training Loss: 6.6879, Validation Loss: 6.2719, Train Acc: 0.1687, Val Acc: 0.1792
# Iteration: 0/3125, Loss: 6.06
# Iteration: 100/3125, Loss: 4.32
# Iteration: 200/3125, Loss: 4.64
# Iteration: 300/3125, Loss: 8.48
# Iteration: 400/3125, Loss: 5.09
# Iteration: 500/3125, Loss: 6.23
# Iteration: 600/3125, Loss: 6.19
# Iteration: 700/3125, Loss: 7.04
# Iteration: 800/3125, Loss: 5.17
# Iteration: 900/3125, Loss: 6.49
# Iteration: 1000/3125, Loss: 6.78
# Iteration: 1100/3125, Loss: 4.61
# Iteration: 1200/3125, Loss: 4.69
# Iteration: 1300/3125, Loss: 9.66
# Iteration: 1400/3125, Loss: 6.47
# Iteration: 1500/3125, Loss: 5.84
# Iteration: 1600/3125, Loss: 6.31
# Iteration: 1700/3125, Loss: 6.23
# Iteration: 1800/3125, Loss: 5.51
# Iteration: 1900/3125, Loss: 5.00
# Iteration: 2000/3125, Loss: 5.94
# Iteration: 2100/3125, Loss: 4.56
# Iteration: 2200/3125, Loss: 7.51
# Iteration: 2300/3125, Loss: 6.51
# Iteration: 2400/3125, Loss: 4.51
# Iteration: 2500/3125, Loss: 6.13
# Iteration: 2600/3125, Loss: 4.91
# Iteration: 2700/3125, Loss: 5.89
# Iteration: 2800/3125, Loss: 4.34
# Epoch [8/20], Training Loss: 5.9686, Validation Loss: 5.6737, Train Acc: 0.1694, Val Acc: 0.1658
# Iteration: 0/3125, Loss: 7.64
# Iteration: 100/3125, Loss: 6.77
# Iteration: 200/3125, Loss: 6.40
# Iteration: 300/3125, Loss: 5.52
# Iteration: 400/3125, Loss: 7.96
# Iteration: 500/3125, Loss: 5.61
# Iteration: 600/3125, Loss: 5.59
# Iteration: 700/3125, Loss: 5.81
# Iteration: 800/3125, Loss: 5.13
# Iteration: 900/3125, Loss: 4.91
# Iteration: 1000/3125, Loss: 4.76
# Iteration: 1100/3125, Loss: 5.98
# Iteration: 1200/3125, Loss: 6.42
# Iteration: 1300/3125, Loss: 6.17
# Iteration: 1400/3125, Loss: 4.89
# Iteration: 1500/3125, Loss: 4.03
# Iteration: 1600/3125, Loss: 5.92
# Iteration: 1700/3125, Loss: 5.83
# Iteration: 1800/3125, Loss: 5.69
# Iteration: 1900/3125, Loss: 5.36
# Iteration: 2000/3125, Loss: 6.49
# Iteration: 2100/3125, Loss: 5.32
# Iteration: 2200/3125, Loss: 6.09
# Iteration: 2300/3125, Loss: 4.78
# Iteration: 2400/3125, Loss: 4.14
# Iteration: 2500/3125, Loss: 6.21
# Iteration: 2600/3125, Loss: 4.30
# Iteration: 2700/3125, Loss: 5.08
# Iteration: 2800/3125, Loss: 5.98
# Epoch [9/20], Training Loss: 5.3861, Validation Loss: 5.1250, Train Acc: 0.1735, Val Acc: 0.1756
# Iteration: 0/3125, Loss: 4.43
# Iteration: 100/3125, Loss: 5.60
# Iteration: 200/3125, Loss: 5.62
# Iteration: 300/3125, Loss: 5.62
# Iteration: 400/3125, Loss: 4.04
# Iteration: 500/3125, Loss: 4.22
# Iteration: 600/3125, Loss: 4.72
# Iteration: 700/3125, Loss: 5.71
# Iteration: 800/3125, Loss: 3.83
# Iteration: 900/3125, Loss: 4.90
# Iteration: 1000/3125, Loss: 4.42
# Iteration: 1100/3125, Loss: 5.32
# Iteration: 1200/3125, Loss: 6.14
# Iteration: 1300/3125, Loss: 4.86
# Iteration: 1400/3125, Loss: 4.77
# Iteration: 1500/3125, Loss: 4.86
# Iteration: 1600/3125, Loss: 4.16
# Iteration: 1700/3125, Loss: 3.98
# Iteration: 1800/3125, Loss: 3.25
# Iteration: 1900/3125, Loss: 4.93
# Iteration: 2000/3125, Loss: 5.40
# Iteration: 2100/3125, Loss: 3.67
# Iteration: 2200/3125, Loss: 5.56
# Iteration: 2300/3125, Loss: 5.44
# Iteration: 2400/3125, Loss: 4.54
# Iteration: 2500/3125, Loss: 4.29
# Iteration: 2600/3125, Loss: 6.06
# Iteration: 2700/3125, Loss: 4.10
# Iteration: 2800/3125, Loss: 5.53
# Epoch [10/20], Training Loss: 4.9173, Validation Loss: 4.7071, Train Acc: 0.1763, Val Acc: 0.1776
# Iteration: 0/3125, Loss: 4.19
# Iteration: 100/3125, Loss: 4.14
# Iteration: 200/3125, Loss: 4.27
# Iteration: 300/3125, Loss: 4.76
# Iteration: 400/3125, Loss: 3.89
# Iteration: 500/3125, Loss: 5.47
# Iteration: 600/3125, Loss: 4.61
# Iteration: 700/3125, Loss: 4.23
# Iteration: 800/3125, Loss: 4.69
# Iteration: 900/3125, Loss: 4.46
# Iteration: 1000/3125, Loss: 4.78
# Iteration: 1100/3125, Loss: 4.90
# Iteration: 1200/3125, Loss: 3.33
# Iteration: 1300/3125, Loss: 3.98
# Iteration: 1400/3125, Loss: 3.91
# Iteration: 1500/3125, Loss: 4.73
# Iteration: 1600/3125, Loss: 4.09
# Iteration: 1700/3125, Loss: 4.87
# Iteration: 1800/3125, Loss: 3.96
# Iteration: 1900/3125, Loss: 3.21
# Iteration: 2000/3125, Loss: 3.99
# Iteration: 2100/3125, Loss: 4.40
# Iteration: 2200/3125, Loss: 4.83
# Iteration: 2300/3125, Loss: 4.32
# Iteration: 2400/3125, Loss: 3.49
# Iteration: 2500/3125, Loss: 3.34
# Iteration: 2600/3125, Loss: 3.88
# Iteration: 2700/3125, Loss: 3.87
# Iteration: 2800/3125, Loss: 5.17
# Epoch [11/20], Training Loss: 4.4374, Validation Loss: 4.3496, Train Acc: 0.1758, Val Acc: 0.1804
# Iteration: 0/3125, Loss: 4.38
# Iteration: 100/3125, Loss: 3.96
# Iteration: 200/3125, Loss: 4.26
# Iteration: 300/3125, Loss: 4.95
# Iteration: 400/3125, Loss: 2.97
# Iteration: 500/3125, Loss: 5.65
# Iteration: 600/3125, Loss: 4.08
# Iteration: 700/3125, Loss: 4.30
# Iteration: 800/3125, Loss: 3.84
# Iteration: 900/3125, Loss: 3.26
# Iteration: 1000/3125, Loss: 4.44
# Iteration: 1100/3125, Loss: 3.50
# Iteration: 1200/3125, Loss: 3.26
# Iteration: 1300/3125, Loss: 4.22
# Iteration: 1400/3125, Loss: 5.33
# Iteration: 1500/3125, Loss: 3.31
# Iteration: 1600/3125, Loss: 3.88
# Iteration: 1700/3125, Loss: 4.41
# Iteration: 1800/3125, Loss: 3.60
# Iteration: 1900/3125, Loss: 5.24
# Iteration: 2000/3125, Loss: 4.86
# Iteration: 2100/3125, Loss: 3.16
# Iteration: 2200/3125, Loss: 6.02
# Iteration: 2300/3125, Loss: 3.81
# Iteration: 2400/3125, Loss: 4.88
# Iteration: 2500/3125, Loss: 2.84
# Iteration: 2600/3125, Loss: 5.59
# Iteration: 2700/3125, Loss: 4.83
# Iteration: 2800/3125, Loss: 5.12
# Epoch [12/20], Training Loss: 4.0914, Validation Loss: 3.9649, Train Acc: 0.1759, Val Acc: 0.1734
# Iteration: 0/3125, Loss: 4.34
# Iteration: 100/3125, Loss: 3.06
# Iteration: 200/3125, Loss: 4.09
# Iteration: 300/3125, Loss: 3.78
# Iteration: 400/3125, Loss: 3.11
# Iteration: 500/3125, Loss: 3.50
# Iteration: 600/3125, Loss: 4.42
# Iteration: 700/3125, Loss: 4.34
# Iteration: 800/3125, Loss: 2.80
# Iteration: 900/3125, Loss: 3.89
# Iteration: 1000/3125, Loss: 5.66
# Iteration: 1100/3125, Loss: 6.02
# Iteration: 1200/3125, Loss: 3.99
# Iteration: 1300/3125, Loss: 5.53
# Iteration: 1400/3125, Loss: 2.91
# Iteration: 1500/3125, Loss: 2.71
# Iteration: 1600/3125, Loss: 4.25
# Iteration: 1700/3125, Loss: 3.38
# Iteration: 1800/3125, Loss: 2.91
# Iteration: 1900/3125, Loss: 2.70
# Iteration: 2000/3125, Loss: 2.97
# Iteration: 2100/3125, Loss: 2.85
# Iteration: 2200/3125, Loss: 3.98
# Iteration: 2300/3125, Loss: 3.04
# Iteration: 2400/3125, Loss: 3.11
# Iteration: 2500/3125, Loss: 2.98
# Iteration: 2600/3125, Loss: 3.87
# Iteration: 2700/3125, Loss: 3.88
# Iteration: 2800/3125, Loss: 3.64
# Epoch [13/20], Training Loss: 3.7789, Validation Loss: 3.6061, Train Acc: 0.1749, Val Acc: 0.1772
# Iteration: 0/3125, Loss: 3.99
# Iteration: 100/3125, Loss: 4.55
# Iteration: 200/3125, Loss: 4.61
# Iteration: 300/3125, Loss: 3.12
# Iteration: 400/3125, Loss: 3.12
# Iteration: 500/3125, Loss: 3.32
# Iteration: 600/3125, Loss: 3.80
# Iteration: 700/3125, Loss: 3.34
# Iteration: 800/3125, Loss: 3.57
# Iteration: 900/3125, Loss: 2.67
# Iteration: 1000/3125, Loss: 4.99
# Iteration: 1100/3125, Loss: 2.48
# Iteration: 1200/3125, Loss: 3.87
# Iteration: 1300/3125, Loss: 2.82
# Iteration: 1400/3125, Loss: 4.41
# Iteration: 1500/3125, Loss: 3.56
# Iteration: 1600/3125, Loss: 4.27
# Iteration: 1700/3125, Loss: 3.14
# Iteration: 1800/3125, Loss: 3.80
# Iteration: 1900/3125, Loss: 3.62
# Iteration: 2000/3125, Loss: 4.00
# Iteration: 2100/3125, Loss: 3.38
# Iteration: 2200/3125, Loss: 3.44
# Iteration: 2300/3125, Loss: 2.51
# Iteration: 2400/3125, Loss: 2.23
# Iteration: 2500/3125, Loss: 3.14
# Iteration: 2600/3125, Loss: 4.47
# Iteration: 2700/3125, Loss: 2.37
# Iteration: 2800/3125, Loss: 3.14
# Epoch [14/20], Training Loss: 3.5191, Validation Loss: 3.3136, Train Acc: 0.1841, Val Acc: 0.1762
# Iteration: 0/3125, Loss: 3.55
# Iteration: 100/3125, Loss: 3.19
# Iteration: 200/3125, Loss: 2.91
# Iteration: 300/3125, Loss: 3.01
# Iteration: 400/3125, Loss: 2.82
# Iteration: 500/3125, Loss: 2.13
# Iteration: 600/3125, Loss: 3.16
# Iteration: 700/3125, Loss: 4.03
# Iteration: 800/3125, Loss: 3.30
# Iteration: 900/3125, Loss: 4.26
# Iteration: 1000/3125, Loss: 4.07
# Iteration: 1100/3125, Loss: 2.69
# Iteration: 1200/3125, Loss: 3.79
# Iteration: 1300/3125, Loss: 3.57
# Iteration: 1400/3125, Loss: 2.96
# Iteration: 1500/3125, Loss: 3.07
# Iteration: 1600/3125, Loss: 2.46
# Iteration: 1700/3125, Loss: 2.25
# Iteration: 1800/3125, Loss: 2.92
# Iteration: 1900/3125, Loss: 3.60
# Iteration: 2000/3125, Loss: 4.85
# Iteration: 2100/3125, Loss: 2.65
# Iteration: 2200/3125, Loss: 3.05
# Iteration: 2300/3125, Loss: 3.69
# Iteration: 2400/3125, Loss: 2.26
# Iteration: 2500/3125, Loss: 3.33
# Iteration: 2600/3125, Loss: 3.06
# Iteration: 2700/3125, Loss: 3.92
# Iteration: 2800/3125, Loss: 3.47
# Epoch [15/20], Training Loss: 3.2883, Validation Loss: 3.1724, Train Acc: 0.1790, Val Acc: 0.1762
# Iteration: 0/3125, Loss: 2.74
# Iteration: 100/3125, Loss: 2.73
# Iteration: 200/3125, Loss: 3.41
# Iteration: 300/3125, Loss: 3.64
# Iteration: 400/3125, Loss: 2.93
# Iteration: 500/3125, Loss: 3.49
# Iteration: 600/3125, Loss: 3.81
# Iteration: 700/3125, Loss: 3.14
# Iteration: 800/3125, Loss: 3.17
# Iteration: 900/3125, Loss: 4.02
# Iteration: 1000/3125, Loss: 2.61
# Iteration: 1100/3125, Loss: 2.92
# Iteration: 1200/3125, Loss: 3.27
# Iteration: 1300/3125, Loss: 2.85
# Iteration: 1400/3125, Loss: 3.24
# Iteration: 1500/3125, Loss: 2.59
# Iteration: 1600/3125, Loss: 2.73
# Iteration: 1700/3125, Loss: 2.38
# Iteration: 1800/3125, Loss: 2.98
# Iteration: 1900/3125, Loss: 4.47
# Iteration: 2000/3125, Loss: 3.60
# Iteration: 2100/3125, Loss: 3.10
# Iteration: 2200/3125, Loss: 2.61
# Iteration: 2300/3125, Loss: 3.20
# Iteration: 2400/3125, Loss: 2.96
# Iteration: 2500/3125, Loss: 2.88
# Iteration: 2600/3125, Loss: 3.17
# Iteration: 2700/3125, Loss: 3.22
# Iteration: 2800/3125, Loss: 2.66
# Epoch [16/20], Training Loss: 3.0961, Validation Loss: 3.0474, Train Acc: 0.1801, Val Acc: 0.1796
# Iteration: 0/3125, Loss: 2.90
# Iteration: 100/3125, Loss: 2.83
# Iteration: 200/3125, Loss: 2.42
# Iteration: 300/3125, Loss: 2.61
# Iteration: 400/3125, Loss: 2.70
# Iteration: 500/3125, Loss: 2.38
# Iteration: 600/3125, Loss: 3.51
# Iteration: 700/3125, Loss: 2.74
# Iteration: 800/3125, Loss: 3.56
# Iteration: 900/3125, Loss: 2.70
# Iteration: 1000/3125, Loss: 2.68
# Iteration: 1100/3125, Loss: 3.22
# Iteration: 1200/3125, Loss: 3.25
# Iteration: 1300/3125, Loss: 1.90
# Iteration: 1400/3125, Loss: 2.29
# Iteration: 1500/3125, Loss: 3.13
# Iteration: 1600/3125, Loss: 2.81
# Iteration: 1700/3125, Loss: 2.81
# Iteration: 1800/3125, Loss: 2.73
# Iteration: 1900/3125, Loss: 2.97
# Iteration: 2000/3125, Loss: 2.48
# Iteration: 2100/3125, Loss: 3.22
# Iteration: 2200/3125, Loss: 3.07
# Iteration: 2300/3125, Loss: 2.00
# Iteration: 2400/3125, Loss: 1.93
# Iteration: 2500/3125, Loss: 2.77
# Iteration: 2600/3125, Loss: 3.10
# Iteration: 2700/3125, Loss: 2.80
# Iteration: 2800/3125, Loss: 2.99
# Epoch [17/20], Training Loss: 2.9244, Validation Loss: 2.8280, Train Acc: 0.1843, Val Acc: 0.1838
# Iteration: 0/3125, Loss: 2.86
# Iteration: 100/3125, Loss: 2.30
# Iteration: 200/3125, Loss: 2.23
# Iteration: 300/3125, Loss: 2.46
# Iteration: 400/3125, Loss: 2.79
# Iteration: 500/3125, Loss: 2.55
# Iteration: 600/3125, Loss: 3.30
# Iteration: 700/3125, Loss: 2.51
# Iteration: 800/3125, Loss: 2.51
# Iteration: 900/3125, Loss: 3.20
# Iteration: 1000/3125, Loss: 2.02
# Iteration: 1100/3125, Loss: 2.74
# Iteration: 1200/3125, Loss: 3.48
# Iteration: 1300/3125, Loss: 2.48
# Iteration: 1400/3125, Loss: 2.75
# Iteration: 1500/3125, Loss: 1.98
# Iteration: 1600/3125, Loss: 3.09
# Iteration: 1700/3125, Loss: 2.67
# Iteration: 1800/3125, Loss: 2.45
# Iteration: 1900/3125, Loss: 2.78
# Iteration: 2000/3125, Loss: 2.53
# Iteration: 2100/3125, Loss: 2.62
# Iteration: 2200/3125, Loss: 2.34
# Iteration: 2300/3125, Loss: 2.72
# Iteration: 2400/3125, Loss: 2.41
# Iteration: 2500/3125, Loss: 2.45
# Iteration: 2600/3125, Loss: 2.70
# Iteration: 2700/3125, Loss: 2.03
# Iteration: 2800/3125, Loss: 2.73
# Epoch [18/20], Training Loss: 2.7963, Validation Loss: 2.7454, Train Acc: 0.1862, Val Acc: 0.1826
# Iteration: 0/3125, Loss: 2.70
# Iteration: 100/3125, Loss: 3.65
# Iteration: 200/3125, Loss: 3.13
# Iteration: 300/3125, Loss: 2.69
# Iteration: 400/3125, Loss: 3.53
# Iteration: 500/3125, Loss: 2.32
# Iteration: 600/3125, Loss: 3.00
# Iteration: 700/3125, Loss: 3.31
# Iteration: 800/3125, Loss: 2.40
# Iteration: 900/3125, Loss: 3.45
# Iteration: 1000/3125, Loss: 2.79
# Iteration: 1100/3125, Loss: 3.10
# Iteration: 1200/3125, Loss: 3.89
# Iteration: 1300/3125, Loss: 3.79
# Iteration: 1400/3125, Loss: 2.78
# Iteration: 1500/3125, Loss: 2.65
# Iteration: 1600/3125, Loss: 2.95
# Iteration: 1700/3125, Loss: 2.71
# Iteration: 1800/3125, Loss: 3.53
# Iteration: 1900/3125, Loss: 2.28
# Iteration: 2000/3125, Loss: 2.39
# Iteration: 2100/3125, Loss: 2.87
# Iteration: 2200/3125, Loss: 3.00
# Iteration: 2300/3125, Loss: 2.95
# Iteration: 2400/3125, Loss: 2.62
# Iteration: 2500/3125, Loss: 2.60
# Iteration: 2600/3125, Loss: 2.54
# Iteration: 2700/3125, Loss: 2.76
# Iteration: 2800/3125, Loss: 2.71
# Epoch [19/20], Training Loss: 2.6834, Validation Loss: 2.6231, Train Acc: 0.1872, Val Acc: 0.1928
# Iteration: 0/3125, Loss: 2.33
# Iteration: 100/3125, Loss: 3.00
# Iteration: 200/3125, Loss: 2.21
# Iteration: 300/3125, Loss: 1.75
# Iteration: 400/3125, Loss: 3.01
# Iteration: 500/3125, Loss: 3.20
# Iteration: 600/3125, Loss: 2.60
# Iteration: 700/3125, Loss: 1.92
# Iteration: 800/3125, Loss: 2.08
# Iteration: 900/3125, Loss: 3.00
# Iteration: 1000/3125, Loss: 2.25
# Iteration: 1100/3125, Loss: 2.46
# Iteration: 1200/3125, Loss: 2.66
# Iteration: 1300/3125, Loss: 1.93
# Iteration: 1400/3125, Loss: 2.83
# Iteration: 1500/3125, Loss: 2.81
# Iteration: 1600/3125, Loss: 2.77
# Iteration: 1700/3125, Loss: 2.58
# Iteration: 1800/3125, Loss: 2.40
# Iteration: 1900/3125, Loss: 3.05
# Iteration: 2000/3125, Loss: 2.69
# Iteration: 2100/3125, Loss: 2.64
# Iteration: 2200/3125, Loss: 2.70
# Iteration: 2300/3125, Loss: 2.54
# Iteration: 2400/3125, Loss: 3.35
# Iteration: 2500/3125, Loss: 1.82
# Iteration: 2600/3125, Loss: 3.12
# Iteration: 2700/3125, Loss: 2.95
# Iteration: 2800/3125, Loss: 2.98
# Epoch [20/20], Training Loss: 2.6077, Validation Loss: 2.5605, Train Acc: 0.1880, Val Acc: 0.1878

# %%
plt.plot(loss_epoch_arr)
plt.show()

# %%
vgg.load_state_dict(best_model)
print(evaluation(trainloader, vgg), evaluation(testloader, vgg))
# Out:
# 0.18108888888888888 0.1805

# %%
# Plot loss curves
plt.plot(range(1, max_epochs+1), train_loss_arr, label='Training Loss')
plt.plot(range(1, max_epochs+1), val_loss_arr, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss Over Epochs')
plt.show()
