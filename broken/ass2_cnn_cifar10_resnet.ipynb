# %%
# %matplotlib inline

# %% [markdown]
# # Load CIFAR10 dataset

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainvalset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
num_classes = len(classes)

trainset, valset = torch.utils.data.random_split(trainvalset, [0.9, 0.1])

trainloader = torch.utils.data.DataLoader(trainset, batch_size=64,
                                          shuffle=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# function to show an image

def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
#   cat   dog  bird  bird

# %% [markdown]
# # ResNet Implementation

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models
import copy
import gc

resnet = models.resnet18(weights=None)

# Prevent weight update from backprop
for param in resnet.parameters():
    param.requires_grad = False

# Change the output layer to 10 classes
in_features = resnet.fc.in_features
resnet.fc = nn.Linear(in_features, num_classes)

for param in resnet.parameters():
    if param.requires_grad:
        print(param.shape)
# Out:
# torch.Size([10, 512])
# torch.Size([10])

# %% [markdown]
# ## Train the model

# %%
batch_size = 16

trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False)
valloader = torch.utils.data.DataLoader(valset, batch_size=batch_size, shuffle=False)

def evaluation(dataloader, model):
    total, correct = 0, 0
    for data in dataloader:
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, pred = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (pred == labels).sum().item()
    return correct / total

resnet = resnet.to(device)
loss_fn = nn.CrossEntropyLoss()
opt = optim.SGD(resnet.parameters(), lr=0.001)

# %%
max_epochs = 20

n_iters = np.ceil(50000/batch_size)

min_loss = 1000

loss_epoch_arr = []
train_loss_arr = []
val_loss_arr = []
train_acc_arr = []
val_acc_arr = []

for epoch in range(max_epochs):
    train_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        opt.zero_grad()
        outputs = resnet(inputs)
        loss = loss_fn(outputs, labels)
        loss.backward()
        opt.step()
        
        train_loss += loss.item()  # Accumulate training loss

        # Update minimum loss and save best model
        if min_loss > loss.item():
            min_loss = loss.item()
            best_model = copy.deepcopy(resnet.state_dict())
            # print('Min loss %0.2f' % min_loss)
        
        # Print training progress every 100 iterations
        if i % 100 == 0:
            print('Iteration: %d/%d, Loss: %0.2f' % (i, np.ceil(50000/batch_size), loss.item()))
            
        # Clear memory
        del inputs, labels, outputs
        torch.cuda.empty_cache()
        gc.collect()
    
    # Record average training loss for the epoch
    train_loss_arr.append(train_loss / len(trainloader))
    
    # Validation loop to calculate validation loss
    val_loss = 0.0
    with torch.no_grad():
        for val_data in valloader:
            val_inputs, val_labels = val_data
            val_inputs, val_labels = val_inputs.to(device), val_labels.to(device)
            val_outputs = resnet(val_inputs)
            v_loss = loss_fn(val_outputs, val_labels)
            val_loss += v_loss.item()
    
    # Record average validation loss for the epoch
    val_loss_arr.append(val_loss / len(valloader))
    
    # Calculate training and validation accuracy
    train_acc = evaluation(trainloader, resnet)
    val_acc = evaluation(valloader, resnet)
    train_acc_arr.append(train_acc)
    val_acc_arr.append(val_acc)
    
    # Print metrics for the epoch
    print(f"Epoch [{epoch+1}/{max_epochs}], Training Loss: {train_loss_arr[-1]:.4f}, Validation Loss: {val_loss_arr[-1]:.4f}, Train Acc: {train_acc:.4f}, Val Acc: {val_acc:.4f}")
    
    # Append final loss of epoch for historical tracking
    loss_epoch_arr.append(train_loss_arr[-1])
# Out:
# Iteration: 0/3125, Loss: 2.59
# Iteration: 100/3125, Loss: 2.30
# Iteration: 200/3125, Loss: 2.49
# Iteration: 300/3125, Loss: 2.27
# Iteration: 400/3125, Loss: 2.50
# Iteration: 500/3125, Loss: 2.29
# Iteration: 600/3125, Loss: 2.09
# Iteration: 700/3125, Loss: 2.02
# Iteration: 800/3125, Loss: 1.96
# Iteration: 900/3125, Loss: 2.14
# Iteration: 1000/3125, Loss: 2.01
# Iteration: 1100/3125, Loss: 2.01
# Iteration: 1200/3125, Loss: 2.00
# Iteration: 1300/3125, Loss: 2.19
# Iteration: 1400/3125, Loss: 1.95
# Iteration: 1500/3125, Loss: 1.87
# Iteration: 1600/3125, Loss: 2.05
# Iteration: 1700/3125, Loss: 2.28
# Iteration: 1800/3125, Loss: 2.01
# Iteration: 1900/3125, Loss: 2.18
# Iteration: 2000/3125, Loss: 1.99
# Iteration: 2100/3125, Loss: 1.96
# Iteration: 2200/3125, Loss: 2.41
# Iteration: 2300/3125, Loss: 2.17
# Iteration: 2400/3125, Loss: 2.17
# Iteration: 2500/3125, Loss: 2.12
# Iteration: 2600/3125, Loss: 2.40
# Iteration: 2700/3125, Loss: 2.06
# Iteration: 2800/3125, Loss: 2.11
# Epoch [1/20], Training Loss: 2.1694, Validation Loss: 2.0800, Train Acc: 0.2553, Val Acc: 0.2568
# Iteration: 0/3125, Loss: 1.95
# Iteration: 100/3125, Loss: 1.96
# Iteration: 200/3125, Loss: 2.38
# Iteration: 300/3125, Loss: 2.25
# Iteration: 400/3125, Loss: 1.83
# Iteration: 500/3125, Loss: 2.01
# Iteration: 600/3125, Loss: 2.14
# Iteration: 700/3125, Loss: 2.20
# Iteration: 800/3125, Loss: 1.86
# Iteration: 900/3125, Loss: 2.38
# Iteration: 1000/3125, Loss: 1.99
# Iteration: 1100/3125, Loss: 1.89
# Iteration: 1200/3125, Loss: 1.78
# Iteration: 1300/3125, Loss: 1.76
# Iteration: 1400/3125, Loss: 1.87
# Iteration: 1500/3125, Loss: 1.69
# Iteration: 1600/3125, Loss: 2.03
# Iteration: 1700/3125, Loss: 1.90
# Iteration: 1800/3125, Loss: 2.06
# Iteration: 1900/3125, Loss: 1.83
# Iteration: 2000/3125, Loss: 2.30
# Iteration: 2100/3125, Loss: 2.00
# Iteration: 2200/3125, Loss: 2.15
# Iteration: 2300/3125, Loss: 1.79
# Iteration: 2400/3125, Loss: 1.80
# Iteration: 2500/3125, Loss: 2.07
# Iteration: 2600/3125, Loss: 1.92
# Iteration: 2700/3125, Loss: 2.05
# Iteration: 2800/3125, Loss: 2.13
# Epoch [2/20], Training Loss: 2.0207, Validation Loss: 2.0103, Train Acc: 0.2892, Val Acc: 0.2804
# Iteration: 0/3125, Loss: 1.87
# Iteration: 100/3125, Loss: 2.05
# Iteration: 200/3125, Loss: 2.14
# Iteration: 300/3125, Loss: 2.19
# Iteration: 400/3125, Loss: 1.79
# Iteration: 500/3125, Loss: 1.93
# Iteration: 600/3125, Loss: 2.01
# Iteration: 700/3125, Loss: 2.22
# Iteration: 800/3125, Loss: 2.05
# Iteration: 900/3125, Loss: 1.76
# Iteration: 1000/3125, Loss: 1.93
# Iteration: 1100/3125, Loss: 2.17
# Iteration: 1200/3125, Loss: 1.95
# Iteration: 1300/3125, Loss: 1.99
# Iteration: 1400/3125, Loss: 1.86
# Iteration: 1500/3125, Loss: 2.40
# Iteration: 1600/3125, Loss: 2.08
# Iteration: 1700/3125, Loss: 1.98
# Iteration: 1800/3125, Loss: 2.00
# Iteration: 1900/3125, Loss: 1.84
# Iteration: 2000/3125, Loss: 1.93
# Iteration: 2100/3125, Loss: 1.70
# Iteration: 2200/3125, Loss: 2.12
# Iteration: 2300/3125, Loss: 1.79
# Iteration: 2400/3125, Loss: 1.95
# Iteration: 2500/3125, Loss: 2.12
# Iteration: 2600/3125, Loss: 2.12
# Iteration: 2700/3125, Loss: 1.95
# Iteration: 2800/3125, Loss: 1.78
# Epoch [3/20], Training Loss: 1.9751, Validation Loss: 1.9849, Train Acc: 0.3009, Val Acc: 0.2916
# Iteration: 0/3125, Loss: 1.97
# Iteration: 100/3125, Loss: 2.00
# Iteration: 200/3125, Loss: 1.87
# Iteration: 300/3125, Loss: 1.84
# Iteration: 400/3125, Loss: 2.02
# Iteration: 500/3125, Loss: 1.90
# Iteration: 600/3125, Loss: 2.21
# Iteration: 700/3125, Loss: 1.97
# Iteration: 800/3125, Loss: 2.24
# Iteration: 900/3125, Loss: 1.99
# Iteration: 1000/3125, Loss: 1.98
# Iteration: 1100/3125, Loss: 2.41
# Iteration: 1200/3125, Loss: 2.21
# Iteration: 1300/3125, Loss: 2.07
# Iteration: 1400/3125, Loss: 1.94
# Iteration: 1500/3125, Loss: 1.78
# Iteration: 1600/3125, Loss: 1.83
# Iteration: 1700/3125, Loss: 1.88
# Iteration: 1800/3125, Loss: 1.79
# Iteration: 1900/3125, Loss: 1.87
# Iteration: 2000/3125, Loss: 1.98
# Iteration: 2100/3125, Loss: 1.81
# Iteration: 2200/3125, Loss: 1.91
# Iteration: 2300/3125, Loss: 1.98
# Iteration: 2400/3125, Loss: 2.06
# Iteration: 2500/3125, Loss: 1.65
# Iteration: 2600/3125, Loss: 1.81
# Iteration: 2700/3125, Loss: 1.82
# Iteration: 2800/3125, Loss: 2.00
# Epoch [4/20], Training Loss: 1.9514, Validation Loss: 1.9707, Train Acc: 0.3083, Val Acc: 0.2952
# Iteration: 0/3125, Loss: 1.82
# Iteration: 100/3125, Loss: 2.09
# Iteration: 200/3125, Loss: 1.71
# Iteration: 300/3125, Loss: 2.00
# Iteration: 400/3125, Loss: 1.68
# Iteration: 500/3125, Loss: 2.26
# Iteration: 600/3125, Loss: 1.86
# Iteration: 700/3125, Loss: 1.92
# Iteration: 800/3125, Loss: 2.22
# Iteration: 900/3125, Loss: 1.96
# Iteration: 1000/3125, Loss: 2.07
# Iteration: 1100/3125, Loss: 1.99
# Iteration: 1200/3125, Loss: 1.92
# Iteration: 1300/3125, Loss: 1.90
# Iteration: 1400/3125, Loss: 1.87
# Iteration: 1500/3125, Loss: 2.13
# Iteration: 1600/3125, Loss: 2.27
# Iteration: 1700/3125, Loss: 2.19
# Iteration: 1800/3125, Loss: 1.83
# Iteration: 1900/3125, Loss: 1.98
# Iteration: 2000/3125, Loss: 2.00
# Iteration: 2100/3125, Loss: 1.91
# Iteration: 2200/3125, Loss: 1.77
# Iteration: 2300/3125, Loss: 1.88
# Iteration: 2400/3125, Loss: 2.13
# Iteration: 2500/3125, Loss: 2.23
# Iteration: 2600/3125, Loss: 2.01
# Iteration: 2700/3125, Loss: 1.94
# Iteration: 2800/3125, Loss: 1.95
# Epoch [5/20], Training Loss: 1.9368, Validation Loss: 1.9626, Train Acc: 0.3098, Val Acc: 0.2990
# Iteration: 0/3125, Loss: 2.10
# Iteration: 100/3125, Loss: 1.95
# Iteration: 200/3125, Loss: 1.95
# Iteration: 300/3125, Loss: 1.75
# Iteration: 400/3125, Loss: 2.24
# Iteration: 500/3125, Loss: 1.94
# Iteration: 600/3125, Loss: 2.06
# Iteration: 700/3125, Loss: 1.99
# Iteration: 800/3125, Loss: 2.08
# Iteration: 900/3125, Loss: 2.01
# Iteration: 1000/3125, Loss: 1.77
# Iteration: 1100/3125, Loss: 2.21
# Iteration: 1200/3125, Loss: 2.05
# Iteration: 1300/3125, Loss: 2.17
# Iteration: 1400/3125, Loss: 1.77
# Iteration: 1500/3125, Loss: 1.85
# Iteration: 1600/3125, Loss: 1.81
# Iteration: 1700/3125, Loss: 1.88
# Iteration: 1800/3125, Loss: 1.54
# Iteration: 1900/3125, Loss: 1.89
# Iteration: 2000/3125, Loss: 2.21
# Iteration: 2100/3125, Loss: 2.26
# Iteration: 2200/3125, Loss: 1.78
# Iteration: 2300/3125, Loss: 1.82
# Iteration: 2400/3125, Loss: 2.04
# Iteration: 2500/3125, Loss: 2.07
# Iteration: 2600/3125, Loss: 2.08
# Iteration: 2700/3125, Loss: 2.00
# Iteration: 2800/3125, Loss: 2.36
# Epoch [6/20], Training Loss: 1.9259, Validation Loss: 1.9567, Train Acc: 0.3137, Val Acc: 0.2954
# Iteration: 0/3125, Loss: 1.93
# Iteration: 100/3125, Loss: 1.91
# Iteration: 200/3125, Loss: 2.24
# Iteration: 300/3125, Loss: 2.02
# Iteration: 400/3125, Loss: 1.68
# Iteration: 500/3125, Loss: 1.55
# Iteration: 600/3125, Loss: 2.08
# Iteration: 700/3125, Loss: 1.66
# Iteration: 800/3125, Loss: 2.03
# Iteration: 900/3125, Loss: 1.58
# Iteration: 1000/3125, Loss: 1.98
# Iteration: 1100/3125, Loss: 1.76
# Iteration: 1200/3125, Loss: 1.81
# Iteration: 1300/3125, Loss: 2.08
# Iteration: 1400/3125, Loss: 1.57
# Iteration: 1500/3125, Loss: 1.83
# Iteration: 1600/3125, Loss: 1.89
# Iteration: 1700/3125, Loss: 1.62
# Iteration: 1800/3125, Loss: 2.08
# Iteration: 1900/3125, Loss: 1.92
# Iteration: 2000/3125, Loss: 1.85
# Iteration: 2100/3125, Loss: 2.21
# Iteration: 2200/3125, Loss: 2.01
# Iteration: 2300/3125, Loss: 1.75
# Iteration: 2400/3125, Loss: 1.96
# Iteration: 2500/3125, Loss: 1.74
# Iteration: 2600/3125, Loss: 2.30
# Iteration: 2700/3125, Loss: 2.20
# Iteration: 2800/3125, Loss: 1.85
# Epoch [7/20], Training Loss: 1.9231, Validation Loss: 1.9527, Train Acc: 0.3184, Val Acc: 0.3004
# Iteration: 0/3125, Loss: 1.75
# Iteration: 100/3125, Loss: 1.75
# Iteration: 200/3125, Loss: 2.31
# Iteration: 300/3125, Loss: 2.00
# Iteration: 400/3125, Loss: 1.83
# Iteration: 500/3125, Loss: 1.78
# Iteration: 600/3125, Loss: 2.12
# Iteration: 700/3125, Loss: 1.48
# Iteration: 800/3125, Loss: 1.88
# Iteration: 900/3125, Loss: 1.81
# Iteration: 1000/3125, Loss: 1.89
# Iteration: 1100/3125, Loss: 2.14
# Iteration: 1200/3125, Loss: 1.69
# Iteration: 1300/3125, Loss: 2.32
# Iteration: 1400/3125, Loss: 1.86
# Iteration: 1500/3125, Loss: 2.09
# Iteration: 1600/3125, Loss: 1.81
# Iteration: 1700/3125, Loss: 1.70
# Iteration: 1800/3125, Loss: 1.86
# Iteration: 1900/3125, Loss: 1.88
# Iteration: 2000/3125, Loss: 1.93
# Iteration: 2100/3125, Loss: 1.85
# Iteration: 2200/3125, Loss: 1.68
# Iteration: 2300/3125, Loss: 2.08
# Iteration: 2400/3125, Loss: 1.95
# Iteration: 2500/3125, Loss: 2.01
# Iteration: 2600/3125, Loss: 2.13
# Iteration: 2700/3125, Loss: 1.86
# Iteration: 2800/3125, Loss: 2.12
# Epoch [8/20], Training Loss: 1.9144, Validation Loss: 1.9513, Train Acc: 0.3158, Val Acc: 0.3030
# Iteration: 0/3125, Loss: 1.57
# Iteration: 100/3125, Loss: 2.25
# Iteration: 200/3125, Loss: 2.01
# Iteration: 300/3125, Loss: 1.80
# Iteration: 400/3125, Loss: 1.85
# Iteration: 500/3125, Loss: 2.07
# Iteration: 600/3125, Loss: 2.17
# Iteration: 700/3125, Loss: 1.91
# Iteration: 800/3125, Loss: 1.94
# Iteration: 900/3125, Loss: 1.96
# Iteration: 1000/3125, Loss: 2.02
# Iteration: 1100/3125, Loss: 2.40
# Iteration: 1200/3125, Loss: 2.17
# Iteration: 1300/3125, Loss: 1.77
# Iteration: 1400/3125, Loss: 1.76
# Iteration: 1500/3125, Loss: 1.99
# Iteration: 1600/3125, Loss: 1.95
# Iteration: 1700/3125, Loss: 1.93
# Iteration: 1800/3125, Loss: 1.79
# Iteration: 1900/3125, Loss: 1.94
# Iteration: 2000/3125, Loss: 1.97
# Iteration: 2100/3125, Loss: 1.88
# Iteration: 2200/3125, Loss: 1.89
# Iteration: 2300/3125, Loss: 1.97
# Iteration: 2400/3125, Loss: 1.99
# Iteration: 2500/3125, Loss: 2.01
# Iteration: 2600/3125, Loss: 2.09
# Iteration: 2700/3125, Loss: 1.83
# Iteration: 2800/3125, Loss: 2.06
# Epoch [9/20], Training Loss: 1.9135, Validation Loss: 1.9473, Train Acc: 0.3156, Val Acc: 0.3024
# Iteration: 0/3125, Loss: 1.92
# Iteration: 100/3125, Loss: 2.24
# Iteration: 200/3125, Loss: 1.90
# Iteration: 300/3125, Loss: 1.99
# Iteration: 400/3125, Loss: 2.26
# Iteration: 500/3125, Loss: 1.80
# Iteration: 600/3125, Loss: 1.83
# Iteration: 700/3125, Loss: 1.95
# Iteration: 800/3125, Loss: 1.92
# Iteration: 900/3125, Loss: 1.70
# Iteration: 1000/3125, Loss: 1.78
# Iteration: 1100/3125, Loss: 1.65
# Iteration: 1200/3125, Loss: 2.01
# Iteration: 1300/3125, Loss: 1.90
# Iteration: 1400/3125, Loss: 1.50
# Iteration: 1500/3125, Loss: 1.90
# Iteration: 1600/3125, Loss: 1.86
# Iteration: 1700/3125, Loss: 1.87
# Iteration: 1800/3125, Loss: 1.81
# Iteration: 1900/3125, Loss: 2.34
# Iteration: 2000/3125, Loss: 2.08
# Iteration: 2100/3125, Loss: 2.03
# Iteration: 2200/3125, Loss: 1.90
# Iteration: 2300/3125, Loss: 1.93
# Iteration: 2400/3125, Loss: 1.88
# Iteration: 2500/3125, Loss: 2.19
# Iteration: 2600/3125, Loss: 2.11
# Iteration: 2700/3125, Loss: 1.63
# Iteration: 2800/3125, Loss: 2.30
# Epoch [10/20], Training Loss: 1.9080, Validation Loss: 1.9517, Train Acc: 0.3185, Val Acc: 0.3008
# Iteration: 0/3125, Loss: 1.99
# Iteration: 100/3125, Loss: 1.94
# Iteration: 200/3125, Loss: 1.60
# Iteration: 300/3125, Loss: 1.93
# Iteration: 400/3125, Loss: 2.11
# Iteration: 500/3125, Loss: 1.88
# Iteration: 600/3125, Loss: 2.11
# Iteration: 700/3125, Loss: 1.92
# Iteration: 800/3125, Loss: 1.97
# Iteration: 900/3125, Loss: 2.01
# Iteration: 1000/3125, Loss: 1.84
# Iteration: 1100/3125, Loss: 1.92
# Iteration: 1200/3125, Loss: 1.86
# Iteration: 1300/3125, Loss: 1.87
# Iteration: 1400/3125, Loss: 1.98
# Iteration: 1500/3125, Loss: 1.90
# Iteration: 1600/3125, Loss: 1.96
# Iteration: 1700/3125, Loss: 1.98
# Iteration: 1800/3125, Loss: 1.80
# Iteration: 1900/3125, Loss: 1.58
# Iteration: 2000/3125, Loss: 2.19
# Iteration: 2100/3125, Loss: 1.62
# Iteration: 2200/3125, Loss: 1.46
# Iteration: 2300/3125, Loss: 2.25
# Iteration: 2400/3125, Loss: 2.22
# Iteration: 2500/3125, Loss: 2.15
# Iteration: 2600/3125, Loss: 1.94
# Iteration: 2700/3125, Loss: 1.84
# Iteration: 2800/3125, Loss: 1.80
# Epoch [11/20], Training Loss: 1.9066, Validation Loss: 1.9519, Train Acc: 0.3214, Val Acc: 0.3094
# Iteration: 0/3125, Loss: 1.82
# Iteration: 100/3125, Loss: 1.94
# Iteration: 200/3125, Loss: 2.21
# Iteration: 300/3125, Loss: 1.93
# Iteration: 400/3125, Loss: 2.13
# Iteration: 500/3125, Loss: 1.68
# Iteration: 600/3125, Loss: 1.87
# Iteration: 700/3125, Loss: 1.82
# Iteration: 800/3125, Loss: 1.85
# Iteration: 900/3125, Loss: 2.17
# Iteration: 1000/3125, Loss: 2.17
# Iteration: 1100/3125, Loss: 2.18
# Iteration: 1200/3125, Loss: 1.73
# Iteration: 1300/3125, Loss: 1.73
# Iteration: 1400/3125, Loss: 1.88
# Iteration: 1500/3125, Loss: 2.14
# Iteration: 1600/3125, Loss: 1.68
# Iteration: 1700/3125, Loss: 1.93
# Iteration: 1800/3125, Loss: 2.16
# Iteration: 1900/3125, Loss: 2.39
# Iteration: 2000/3125, Loss: 1.79
# Iteration: 2100/3125, Loss: 1.82
# Iteration: 2200/3125, Loss: 1.59
# Iteration: 2300/3125, Loss: 1.59
# Iteration: 2400/3125, Loss: 1.94
# Iteration: 2500/3125, Loss: 1.76
# Iteration: 2600/3125, Loss: 2.04
# Iteration: 2700/3125, Loss: 1.82
# Iteration: 2800/3125, Loss: 2.10
# Epoch [12/20], Training Loss: 1.9042, Validation Loss: 1.9441, Train Acc: 0.3195, Val Acc: 0.3080
# Iteration: 0/3125, Loss: 2.04
# Iteration: 100/3125, Loss: 1.62
# Iteration: 200/3125, Loss: 2.04
# Iteration: 300/3125, Loss: 1.97
# Iteration: 400/3125, Loss: 1.95
# Iteration: 500/3125, Loss: 1.75
# Iteration: 600/3125, Loss: 2.14
# Iteration: 700/3125, Loss: 2.04
# Iteration: 800/3125, Loss: 2.08
# Iteration: 900/3125, Loss: 1.83
# Iteration: 1000/3125, Loss: 2.10
# Iteration: 1100/3125, Loss: 2.18
# Iteration: 1200/3125, Loss: 2.10
# Iteration: 1300/3125, Loss: 1.73
# Iteration: 1400/3125, Loss: 1.88
# Iteration: 1500/3125, Loss: 1.75
# Iteration: 1600/3125, Loss: 2.14
# Iteration: 1700/3125, Loss: 1.82
# Iteration: 1800/3125, Loss: 1.63
# Iteration: 1900/3125, Loss: 2.10
# Iteration: 2000/3125, Loss: 2.12
# Iteration: 2100/3125, Loss: 2.09
# Iteration: 2200/3125, Loss: 1.81
# Iteration: 2300/3125, Loss: 2.12
# Iteration: 2400/3125, Loss: 2.06
# Iteration: 2500/3125, Loss: 1.84
# Iteration: 2600/3125, Loss: 2.04
# Iteration: 2700/3125, Loss: 2.10
# Iteration: 2800/3125, Loss: 1.76
# Epoch [13/20], Training Loss: 1.9086, Validation Loss: 1.9468, Train Acc: 0.3203, Val Acc: 0.3122
# Iteration: 0/3125, Loss: 1.86
# Iteration: 100/3125, Loss: 1.60
# Iteration: 200/3125, Loss: 2.20
# Iteration: 300/3125, Loss: 1.95
# Iteration: 400/3125, Loss: 1.56
# Iteration: 500/3125, Loss: 1.96
# Iteration: 600/3125, Loss: 1.90
# Iteration: 700/3125, Loss: 2.12
# Iteration: 800/3125, Loss: 1.73
# Iteration: 900/3125, Loss: 1.80
# Iteration: 1000/3125, Loss: 1.60
# Iteration: 1100/3125, Loss: 1.99
# Iteration: 1200/3125, Loss: 2.03
# Iteration: 1300/3125, Loss: 1.95
# Iteration: 1400/3125, Loss: 2.10
# Iteration: 1500/3125, Loss: 1.62
# Iteration: 1600/3125, Loss: 1.67
# Iteration: 1700/3125, Loss: 1.80
# Iteration: 1800/3125, Loss: 2.19
# Iteration: 1900/3125, Loss: 2.11
# Iteration: 2000/3125, Loss: 1.69
# Iteration: 2100/3125, Loss: 1.60
# Iteration: 2200/3125, Loss: 2.23
# Iteration: 2300/3125, Loss: 1.69
# Iteration: 2400/3125, Loss: 1.95
# Iteration: 2500/3125, Loss: 1.84
# Iteration: 2600/3125, Loss: 2.13
# Iteration: 2700/3125, Loss: 1.66
# Iteration: 2800/3125, Loss: 1.42
# Epoch [14/20], Training Loss: 1.9016, Validation Loss: 1.9386, Train Acc: 0.3245, Val Acc: 0.3150
# Iteration: 0/3125, Loss: 2.04
# Iteration: 100/3125, Loss: 2.28
# Iteration: 200/3125, Loss: 2.20
# Iteration: 300/3125, Loss: 1.92
# Iteration: 400/3125, Loss: 2.43
# Iteration: 500/3125, Loss: 1.72
# Iteration: 600/3125, Loss: 1.96
# Iteration: 700/3125, Loss: 1.80
# Iteration: 800/3125, Loss: 1.85
# Iteration: 900/3125, Loss: 2.29
# Iteration: 1000/3125, Loss: 2.05
# Iteration: 1100/3125, Loss: 2.08
# Iteration: 1200/3125, Loss: 2.21
# Iteration: 1300/3125, Loss: 2.26
# Iteration: 1400/3125, Loss: 2.01
# Iteration: 1500/3125, Loss: 1.70
# Iteration: 1600/3125, Loss: 1.95
# Iteration: 1700/3125, Loss: 1.80
# Iteration: 1800/3125, Loss: 2.09
# Iteration: 1900/3125, Loss: 2.12
# Iteration: 2000/3125, Loss: 1.64
# Iteration: 2100/3125, Loss: 1.76
# Iteration: 2200/3125, Loss: 1.86
# Iteration: 2300/3125, Loss: 2.21
# Iteration: 2400/3125, Loss: 2.03
# Iteration: 2500/3125, Loss: 1.92
# Iteration: 2600/3125, Loss: 1.93
# Iteration: 2700/3125, Loss: 1.65
# Iteration: 2800/3125, Loss: 2.14
# Epoch [15/20], Training Loss: 1.8994, Validation Loss: 1.9429, Train Acc: 0.3233, Val Acc: 0.3120
# Iteration: 0/3125, Loss: 1.90
# Iteration: 100/3125, Loss: 1.95
# Iteration: 200/3125, Loss: 1.58
# Iteration: 300/3125, Loss: 2.07
# Iteration: 400/3125, Loss: 2.19
# Iteration: 500/3125, Loss: 1.65
# Iteration: 600/3125, Loss: 2.15
# Iteration: 700/3125, Loss: 1.98
# Iteration: 800/3125, Loss: 1.96
# Iteration: 900/3125, Loss: 1.60
# Iteration: 1000/3125, Loss: 1.80
# Iteration: 1100/3125, Loss: 1.70
# Iteration: 1200/3125, Loss: 1.74
# Iteration: 1300/3125, Loss: 1.54
# Iteration: 1400/3125, Loss: 2.09
# Iteration: 1500/3125, Loss: 2.13
# Iteration: 1600/3125, Loss: 1.79
# Iteration: 1700/3125, Loss: 1.98
# Iteration: 1800/3125, Loss: 2.27
# Iteration: 1900/3125, Loss: 1.85
# Iteration: 2000/3125, Loss: 1.72
# Iteration: 2100/3125, Loss: 1.60
# Iteration: 2200/3125, Loss: 1.64
# Iteration: 2300/3125, Loss: 2.26
# Iteration: 2400/3125, Loss: 2.05
# Iteration: 2500/3125, Loss: 1.95
# Iteration: 2600/3125, Loss: 1.74
# Iteration: 2700/3125, Loss: 2.00
# Iteration: 2800/3125, Loss: 1.61
# Epoch [16/20], Training Loss: 1.9026, Validation Loss: 1.9484, Train Acc: 0.3222, Val Acc: 0.3072
# Iteration: 0/3125, Loss: 2.05
# Iteration: 100/3125, Loss: 2.18
# Iteration: 200/3125, Loss: 1.71
# Iteration: 300/3125, Loss: 2.03
# Iteration: 400/3125, Loss: 1.95
# Iteration: 500/3125, Loss: 2.10
# Iteration: 600/3125, Loss: 2.02
# Iteration: 700/3125, Loss: 1.76
# Iteration: 800/3125, Loss: 2.04
# Iteration: 900/3125, Loss: 1.90
# Iteration: 1000/3125, Loss: 1.79
# Iteration: 1100/3125, Loss: 2.03
# Iteration: 1200/3125, Loss: 1.97
# Iteration: 1300/3125, Loss: 1.64
# Iteration: 1400/3125, Loss: 2.10
# Iteration: 1500/3125, Loss: 1.97
# Iteration: 1600/3125, Loss: 2.08
# Iteration: 1700/3125, Loss: 1.50
# Iteration: 1800/3125, Loss: 1.59
# Iteration: 1900/3125, Loss: 1.78
# Iteration: 2000/3125, Loss: 1.59
# Iteration: 2100/3125, Loss: 1.86
# Iteration: 2200/3125, Loss: 1.60
# Iteration: 2300/3125, Loss: 1.87
# Iteration: 2400/3125, Loss: 1.95
# Iteration: 2500/3125, Loss: 1.67
# Iteration: 2600/3125, Loss: 1.84
# Iteration: 2700/3125, Loss: 2.10
# Iteration: 2800/3125, Loss: 1.76
# Epoch [17/20], Training Loss: 1.8978, Validation Loss: 1.9448, Train Acc: 0.3224, Val Acc: 0.3072
# Iteration: 0/3125, Loss: 1.59
# Iteration: 100/3125, Loss: 2.04
# Iteration: 200/3125, Loss: 1.95
# Iteration: 300/3125, Loss: 2.05
# Iteration: 400/3125, Loss: 1.89
# Iteration: 500/3125, Loss: 2.15
# Iteration: 600/3125, Loss: 1.73
# Iteration: 700/3125, Loss: 1.83
# Iteration: 800/3125, Loss: 1.62
# Iteration: 900/3125, Loss: 2.00
# Iteration: 1000/3125, Loss: 1.92
# Iteration: 1100/3125, Loss: 1.92
# Iteration: 1200/3125, Loss: 2.10
# Iteration: 1300/3125, Loss: 1.77
# Iteration: 1400/3125, Loss: 2.03
# Iteration: 1500/3125, Loss: 2.20
# Iteration: 1600/3125, Loss: 2.23
# Iteration: 1700/3125, Loss: 1.94
# Iteration: 1800/3125, Loss: 1.98
# Iteration: 1900/3125, Loss: 1.89
# Iteration: 2000/3125, Loss: 2.15
# Iteration: 2100/3125, Loss: 2.33
# Iteration: 2200/3125, Loss: 2.15
# Iteration: 2300/3125, Loss: 1.63
# Iteration: 2400/3125, Loss: 1.61
# Iteration: 2500/3125, Loss: 1.81
# Iteration: 2600/3125, Loss: 1.70
# Iteration: 2700/3125, Loss: 1.91
# Iteration: 2800/3125, Loss: 1.69
# Epoch [18/20], Training Loss: 1.9038, Validation Loss: 1.9513, Train Acc: 0.3236, Val Acc: 0.3066
# Iteration: 0/3125, Loss: 2.03
# Iteration: 100/3125, Loss: 1.99
# Iteration: 200/3125, Loss: 2.04
# Iteration: 300/3125, Loss: 1.87
# Iteration: 400/3125, Loss: 1.79
# Iteration: 500/3125, Loss: 1.99
# Iteration: 600/3125, Loss: 1.99
# Iteration: 700/3125, Loss: 1.73
# Iteration: 800/3125, Loss: 1.81
# Iteration: 900/3125, Loss: 1.68
# Iteration: 1000/3125, Loss: 2.23
# Iteration: 1100/3125, Loss: 1.78
# Iteration: 1200/3125, Loss: 1.85
# Iteration: 1300/3125, Loss: 1.60
# Iteration: 1400/3125, Loss: 1.87
# Iteration: 1500/3125, Loss: 1.75
# Iteration: 1600/3125, Loss: 1.60
# Iteration: 1700/3125, Loss: 1.89
# Iteration: 1800/3125, Loss: 2.00
# Iteration: 1900/3125, Loss: 2.09
# Iteration: 2000/3125, Loss: 1.79
# Iteration: 2100/3125, Loss: 1.60
# Iteration: 2200/3125, Loss: 1.89
# Iteration: 2300/3125, Loss: 1.85
# Iteration: 2400/3125, Loss: 1.83
# Iteration: 2500/3125, Loss: 1.83
# Iteration: 2600/3125, Loss: 1.87
# Iteration: 2700/3125, Loss: 1.99
# Iteration: 2800/3125, Loss: 2.14
# Epoch [19/20], Training Loss: 1.8971, Validation Loss: 1.9428, Train Acc: 0.3249, Val Acc: 0.3124
# Iteration: 0/3125, Loss: 1.92
# Iteration: 100/3125, Loss: 1.96
# Iteration: 200/3125, Loss: 1.78
# Iteration: 300/3125, Loss: 1.77
# Iteration: 400/3125, Loss: 2.14
# Iteration: 500/3125, Loss: 1.58
# Iteration: 600/3125, Loss: 2.00
# Iteration: 700/3125, Loss: 1.92
# Iteration: 800/3125, Loss: 1.66
# Iteration: 900/3125, Loss: 1.73
# Iteration: 1000/3125, Loss: 1.76
# Iteration: 1100/3125, Loss: 2.02
# Iteration: 1200/3125, Loss: 2.37
# Iteration: 1300/3125, Loss: 1.90
# Iteration: 1400/3125, Loss: 2.27
# Iteration: 1500/3125, Loss: 2.16
# Iteration: 1600/3125, Loss: 2.02
# Iteration: 1700/3125, Loss: 1.68
# Iteration: 1800/3125, Loss: 1.79
# Iteration: 1900/3125, Loss: 2.00
# Iteration: 2000/3125, Loss: 1.93
# Iteration: 2100/3125, Loss: 1.72
# Iteration: 2200/3125, Loss: 1.74
# Iteration: 2300/3125, Loss: 2.02
# Iteration: 2400/3125, Loss: 1.96
# Iteration: 2500/3125, Loss: 2.07
# Iteration: 2600/3125, Loss: 2.16
# Iteration: 2700/3125, Loss: 2.08
# Iteration: 2800/3125, Loss: 2.09
# Epoch [20/20], Training Loss: 1.8980, Validation Loss: 1.9380, Train Acc: 0.3263, Val Acc: 0.3136

# %%
plt.plot(loss_epoch_arr)
plt.show()

# %%
resnet.load_state_dict(best_model)
print(evaluation(trainloader, resnet), evaluation(testloader, resnet))
# Out:
# 0.3148 0.3052

# %%
# Plot loss curves
plt.plot(range(1, max_epochs+1), train_loss_arr, label='Training Loss')
plt.plot(range(1, max_epochs+1), val_loss_arr, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss Over Epochs')
plt.show()

# %%
# Plot accuracy curves
plt.plot(range(1, max_epochs+1), train_acc_arr, label='Training Accuracy')
plt.plot(range(1, max_epochs+1), val_acc_arr, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy Over Epochs')
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Calculate predictions on validation set
all_preds = []
all_labels = []
with torch.no_grad():
    for data in valloader:
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = resnet(inputs)
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# %%
# Generate confusion matrix
cm = confusion_matrix(all_labels, all_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()
