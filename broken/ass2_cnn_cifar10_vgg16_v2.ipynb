# %%
# %matplotlib inline

# %% [markdown]
# # Load CIFAR10 dataset

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainvalset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
num_classes = len(classes)

trainset, valset = torch.utils.data.random_split(trainvalset, [0.9, 0.1])

trainloader = torch.utils.data.DataLoader(trainset, batch_size=64,
                                          shuffle=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# function to show an image

def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
#   dog  deer horse   cat

# %% [markdown]
# # VGG16 Implementation

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models
from torchvision.models.vgg import VGG16_BN_Weights
import copy
import gc

vgg = models.vgg16_bn(weights=VGG16_BN_Weights.DEFAULT)

# Prevent weight update from backprop
for param in vgg.parameters():
    param.requires_grad = False

# Change the output layer to 10 classes
final_in_features = vgg.classifier[6].in_features
vgg.classifier[6] = nn.Linear(final_in_features, num_classes)

for param in vgg.parameters():
    if param.requires_grad:
        print(param.shape)
# Out:
# torch.Size([10, 4096])
# torch.Size([10])

# %% [markdown]
# ## Train the model

# %%
batch_size = 16

trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False)
valloader = torch.utils.data.DataLoader(valset, batch_size=batch_size, shuffle=False)

def evaluation(dataloader, model):
    total, correct = 0, 0
    for data in dataloader:
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, pred = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (pred == labels).sum().item()
    return correct / total

vgg = vgg.to(device)
loss_fn = nn.CrossEntropyLoss()
opt = optim.SGD(vgg.parameters(), lr=0.001)

# %%
max_epochs = 20

n_iters = np.ceil(50000/batch_size)

min_loss = 1000

loss_epoch_arr = []
train_loss_arr = []
val_loss_arr = []
train_acc_arr = []
val_acc_arr = []

for epoch in range(max_epochs):
    train_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        opt.zero_grad()
        outputs = vgg(inputs)
        loss = loss_fn(outputs, labels)
        loss.backward()
        opt.step()
        
        train_loss += loss.item()  # Accumulate training loss

        # Update minimum loss and save best model
        if min_loss > loss.item():
            min_loss = loss.item()
            best_model = copy.deepcopy(vgg.state_dict())
            # print('Min loss %0.2f' % min_loss)
        
        # Print training progress every 100 iterations
        if i % 100 == 0:
            print('Iteration: %d/%d, Loss: %0.2f' % (i, np.ceil(50000/batch_size), loss.item()))
            
        # Clear memory
        del inputs, labels, outputs
        torch.cuda.empty_cache()
        gc.collect()
    
    # Record average training loss for the epoch
    train_loss_arr.append(train_loss / len(trainloader))
    
    # Validation loop to calculate validation loss
    val_loss = 0.0
    with torch.no_grad():
        for val_data in valloader:
            val_inputs, val_labels = val_data
            val_inputs, val_labels = val_inputs.to(device), val_labels.to(device)
            val_outputs = vgg(val_inputs)
            v_loss = loss_fn(val_outputs, val_labels)
            val_loss += v_loss.item()
    
    # Record average validation loss for the epoch
    val_loss_arr.append(val_loss / len(valloader))
    
    # Calculate training and validation accuracy
    train_acc = evaluation(trainloader, vgg)
    val_acc = evaluation(valloader, vgg)
    train_acc_arr.append(train_acc)
    val_acc_arr.append(val_acc)
    
    # Print metrics for the epoch
    print(f"Epoch [{epoch+1}/{max_epochs}], Training Loss: {train_loss_arr[-1]:.4f}, Validation Loss: {val_loss_arr[-1]:.4f}, Train Acc: {train_acc:.4f}, Val Acc: {val_acc:.4f}")
    
    # Append final loss of epoch for historical tracking
    loss_epoch_arr.append(train_loss_arr[-1])
# Out:
# Iteration: 0/3125, Loss: 2.63
# Iteration: 100/3125, Loss: 1.66
# Iteration: 200/3125, Loss: 1.43
# Iteration: 300/3125, Loss: 1.65
# Iteration: 400/3125, Loss: 1.74
# Iteration: 500/3125, Loss: 0.92
# Iteration: 600/3125, Loss: 2.16
# Iteration: 700/3125, Loss: 2.57
# Iteration: 800/3125, Loss: 1.81
# Iteration: 900/3125, Loss: 1.75
# Iteration: 1000/3125, Loss: 1.79
# Iteration: 1100/3125, Loss: 3.03
# Iteration: 1200/3125, Loss: 2.26
# Iteration: 1300/3125, Loss: 2.44
# Iteration: 1400/3125, Loss: 2.42
# Iteration: 1500/3125, Loss: 2.03
# Iteration: 1600/3125, Loss: 1.15
# Iteration: 1700/3125, Loss: 3.08
# Iteration: 1800/3125, Loss: 2.03
# Iteration: 1900/3125, Loss: 2.14
# Iteration: 2000/3125, Loss: 2.76
# Iteration: 2100/3125, Loss: 2.24
# Iteration: 2200/3125, Loss: 1.75
# Iteration: 2300/3125, Loss: 2.92
# Iteration: 2400/3125, Loss: 2.25
# Iteration: 2500/3125, Loss: 2.14
# Iteration: 2600/3125, Loss: 2.90
# Iteration: 2700/3125, Loss: 2.21
# Iteration: 2800/3125, Loss: 2.50
# Epoch [1/20], Training Loss: 2.1492, Validation Loss: 2.2549, Train Acc: 0.3743, Val Acc: 0.3760
# Iteration: 0/3125, Loss: 2.38
# Iteration: 100/3125, Loss: 1.53
# Iteration: 200/3125, Loss: 2.92
# Iteration: 300/3125, Loss: 1.72
# Iteration: 400/3125, Loss: 2.08
# Iteration: 500/3125, Loss: 1.59
# Iteration: 600/3125, Loss: 2.37
# Iteration: 700/3125, Loss: 2.36
# Iteration: 800/3125, Loss: 2.17
# Iteration: 900/3125, Loss: 2.40
# Iteration: 1000/3125, Loss: 1.78
# Iteration: 1100/3125, Loss: 2.41
# Iteration: 1200/3125, Loss: 2.93
# Iteration: 1300/3125, Loss: 1.39
# Iteration: 1400/3125, Loss: 1.97
# Iteration: 1500/3125, Loss: 2.86
# Iteration: 1600/3125, Loss: 1.81
# Iteration: 1700/3125, Loss: 1.96
# Iteration: 1800/3125, Loss: 2.75
# Iteration: 1900/3125, Loss: 1.64
# Iteration: 2000/3125, Loss: 2.77
# Iteration: 2100/3125, Loss: 1.73
# Iteration: 2200/3125, Loss: 2.29
# Iteration: 2300/3125, Loss: 1.99
# Iteration: 2400/3125, Loss: 3.33
# Iteration: 2500/3125, Loss: 2.07
# Iteration: 2600/3125, Loss: 2.37
# Iteration: 2700/3125, Loss: 1.36
# Iteration: 2800/3125, Loss: 2.90
# Epoch [2/20], Training Loss: 2.2569, Validation Loss: 2.3676, Train Acc: 0.3734, Val Acc: 0.3684
# Iteration: 0/3125, Loss: 2.49
# Iteration: 100/3125, Loss: 2.83
# Iteration: 200/3125, Loss: 1.83
# Iteration: 300/3125, Loss: 2.03
# Iteration: 400/3125, Loss: 2.28
# Iteration: 500/3125, Loss: 2.99
# Iteration: 600/3125, Loss: 1.87
# Iteration: 700/3125, Loss: 2.17
# Iteration: 800/3125, Loss: 2.66
# Iteration: 900/3125, Loss: 3.04
# Iteration: 1000/3125, Loss: 3.32
# Iteration: 1100/3125, Loss: 2.08
# Iteration: 1200/3125, Loss: 2.25
# Iteration: 1300/3125, Loss: 1.53
# Iteration: 1400/3125, Loss: 1.81
# Iteration: 1500/3125, Loss: 2.10
# Iteration: 1600/3125, Loss: 2.30
# Iteration: 1700/3125, Loss: 1.82
# Iteration: 1800/3125, Loss: 2.17
# Iteration: 1900/3125, Loss: 3.38
# Iteration: 2000/3125, Loss: 2.27
# Iteration: 2100/3125, Loss: 2.23
# Iteration: 2200/3125, Loss: 2.81
# Iteration: 2300/3125, Loss: 2.42
# Iteration: 2400/3125, Loss: 2.01
# Iteration: 2500/3125, Loss: 3.13
# Iteration: 2600/3125, Loss: 2.88
# Iteration: 2700/3125, Loss: 2.18
# Iteration: 2800/3125, Loss: 2.41
# Epoch [3/20], Training Loss: 2.2999, Validation Loss: 2.3646, Train Acc: 0.3896, Val Acc: 0.3788
# Iteration: 0/3125, Loss: 3.74
# Iteration: 100/3125, Loss: 2.22
# Iteration: 200/3125, Loss: 3.93
# Iteration: 300/3125, Loss: 1.85
# Iteration: 400/3125, Loss: 1.44
# Iteration: 500/3125, Loss: 4.27
# Iteration: 600/3125, Loss: 1.77
# Iteration: 700/3125, Loss: 2.56
# Iteration: 800/3125, Loss: 3.00
# Iteration: 900/3125, Loss: 1.54
# Iteration: 1000/3125, Loss: 2.84
# Iteration: 1100/3125, Loss: 2.15
# Iteration: 1200/3125, Loss: 1.55
# Iteration: 1300/3125, Loss: 3.55
# Iteration: 1400/3125, Loss: 4.44
# Iteration: 1500/3125, Loss: 3.26
# Iteration: 1600/3125, Loss: 2.08
# Iteration: 1700/3125, Loss: 2.90
# Iteration: 1800/3125, Loss: 2.95
# Iteration: 1900/3125, Loss: 3.08
# Iteration: 2000/3125, Loss: 1.66
# Iteration: 2100/3125, Loss: 2.97
# Iteration: 2200/3125, Loss: 2.70
# Iteration: 2300/3125, Loss: 2.55
# Iteration: 2400/3125, Loss: 3.29
# Iteration: 2500/3125, Loss: 2.43
# Iteration: 2600/3125, Loss: 2.19
# Iteration: 2700/3125, Loss: 1.92
# Iteration: 2800/3125, Loss: 2.62
# Epoch [4/20], Training Loss: 2.3309, Validation Loss: 2.2576, Train Acc: 0.3904, Val Acc: 0.3924
# Iteration: 0/3125, Loss: 1.35
# Iteration: 100/3125, Loss: 2.79
# Iteration: 200/3125, Loss: 1.95
# Iteration: 300/3125, Loss: 2.75
# Iteration: 400/3125, Loss: 2.76
# Iteration: 500/3125, Loss: 3.33
# Iteration: 600/3125, Loss: 3.02
# Iteration: 700/3125, Loss: 1.96
# Iteration: 800/3125, Loss: 1.70
# Iteration: 900/3125, Loss: 2.51
# Iteration: 1000/3125, Loss: 1.85
# Iteration: 1100/3125, Loss: 2.52
# Iteration: 1200/3125, Loss: 2.18
# Iteration: 1300/3125, Loss: 2.20
# Iteration: 1400/3125, Loss: 2.51
# Iteration: 1500/3125, Loss: 2.41
# Iteration: 1600/3125, Loss: 1.79
# Iteration: 1700/3125, Loss: 2.30
# Iteration: 1800/3125, Loss: 2.97
# Iteration: 1900/3125, Loss: 3.02
# Iteration: 2000/3125, Loss: 2.52
# Iteration: 2100/3125, Loss: 2.58
# Iteration: 2200/3125, Loss: 2.01
# Iteration: 2300/3125, Loss: 2.75
# Iteration: 2400/3125, Loss: 2.05
# Iteration: 2500/3125, Loss: 2.48
# Iteration: 2600/3125, Loss: 3.65
# Iteration: 2700/3125, Loss: 3.13
# Iteration: 2800/3125, Loss: 2.78
# Epoch [5/20], Training Loss: 2.3155, Validation Loss: 2.3816, Train Acc: 0.3722, Val Acc: 0.3676
# Iteration: 0/3125, Loss: 2.19
# Iteration: 100/3125, Loss: 2.71
# Iteration: 200/3125, Loss: 1.76
# Iteration: 300/3125, Loss: 1.44
# Iteration: 400/3125, Loss: 2.65
# Iteration: 500/3125, Loss: 2.88
# Iteration: 600/3125, Loss: 2.13
# Iteration: 700/3125, Loss: 2.75
# Iteration: 800/3125, Loss: 1.80
# Iteration: 900/3125, Loss: 1.36
# Iteration: 1000/3125, Loss: 2.82
# Iteration: 1100/3125, Loss: 2.22
# Iteration: 1200/3125, Loss: 3.54
# Iteration: 1300/3125, Loss: 1.85
# Iteration: 1400/3125, Loss: 1.84
# Iteration: 1500/3125, Loss: 1.96
# Iteration: 1600/3125, Loss: 2.82
# Iteration: 1700/3125, Loss: 2.42
# Iteration: 1800/3125, Loss: 1.86
# Iteration: 1900/3125, Loss: 1.42
# Iteration: 2000/3125, Loss: 2.21
# Iteration: 2100/3125, Loss: 3.21
# Iteration: 2200/3125, Loss: 2.34
# Iteration: 2300/3125, Loss: 2.22
# Iteration: 2400/3125, Loss: 2.32
# Iteration: 2500/3125, Loss: 2.01
# Iteration: 2600/3125, Loss: 2.26
# Iteration: 2700/3125, Loss: 2.72
# Iteration: 2800/3125, Loss: 3.53
# Epoch [6/20], Training Loss: 2.3206, Validation Loss: 2.4570, Train Acc: 0.3750, Val Acc: 0.3698
# Iteration: 0/3125, Loss: 3.16
# Iteration: 100/3125, Loss: 2.00
# Iteration: 200/3125, Loss: 3.19
# Iteration: 300/3125, Loss: 2.64
# Iteration: 400/3125, Loss: 2.53
# Iteration: 500/3125, Loss: 2.56
# Iteration: 600/3125, Loss: 2.18
# Iteration: 700/3125, Loss: 2.30
# Iteration: 800/3125, Loss: 1.72
# Iteration: 900/3125, Loss: 1.85
# Iteration: 1000/3125, Loss: 2.51
# Iteration: 1100/3125, Loss: 3.49
# Iteration: 1200/3125, Loss: 2.58
# Iteration: 1300/3125, Loss: 2.27
# Iteration: 1400/3125, Loss: 2.20
# Iteration: 1500/3125, Loss: 2.13
# Iteration: 1600/3125, Loss: 1.57
# Iteration: 1700/3125, Loss: 1.59
# Iteration: 1800/3125, Loss: 1.27
# Iteration: 1900/3125, Loss: 2.17
# Iteration: 2000/3125, Loss: 3.46
# Iteration: 2100/3125, Loss: 2.51
# Iteration: 2200/3125, Loss: 2.35
# Iteration: 2300/3125, Loss: 3.22
# Iteration: 2400/3125, Loss: 1.18
# Iteration: 2500/3125, Loss: 2.13
# Iteration: 2600/3125, Loss: 1.93
# Iteration: 2700/3125, Loss: 1.40
# Iteration: 2800/3125, Loss: 4.07
# Epoch [7/20], Training Loss: 2.3258, Validation Loss: 2.3770, Train Acc: 0.3709, Val Acc: 0.3632
# Iteration: 0/3125, Loss: 2.51
# Iteration: 100/3125, Loss: 0.63
# Iteration: 200/3125, Loss: 2.19
# Iteration: 300/3125, Loss: 1.15
# Iteration: 400/3125, Loss: 1.34
# Iteration: 500/3125, Loss: 2.26
# Iteration: 600/3125, Loss: 3.07
# Iteration: 700/3125, Loss: 2.68
# Iteration: 800/3125, Loss: 3.43
# Iteration: 900/3125, Loss: 2.70
# Iteration: 1000/3125, Loss: 2.47
# Iteration: 1100/3125, Loss: 2.63
# Iteration: 1200/3125, Loss: 1.84
# Iteration: 1300/3125, Loss: 1.85
# Iteration: 1400/3125, Loss: 2.32
# Iteration: 1500/3125, Loss: 2.22
# Iteration: 1600/3125, Loss: 1.94
# Iteration: 1700/3125, Loss: 1.82
# Iteration: 1800/3125, Loss: 3.55
# Iteration: 1900/3125, Loss: 2.17
# Iteration: 2000/3125, Loss: 2.15
# Iteration: 2100/3125, Loss: 2.15
# Iteration: 2200/3125, Loss: 2.75
# Iteration: 2300/3125, Loss: 1.52
# Iteration: 2400/3125, Loss: 2.16
# Iteration: 2500/3125, Loss: 3.10
# Iteration: 2600/3125, Loss: 3.08
# Iteration: 2700/3125, Loss: 3.08
# Iteration: 2800/3125, Loss: 1.62
# Epoch [8/20], Training Loss: 2.3212, Validation Loss: 2.3460, Train Acc: 0.3844, Val Acc: 0.3688
# Iteration: 0/3125, Loss: 1.92
# Iteration: 100/3125, Loss: 2.34
# Iteration: 200/3125, Loss: 2.65
# Iteration: 300/3125, Loss: 1.84
# Iteration: 400/3125, Loss: 3.44
# Iteration: 500/3125, Loss: 2.51
# Iteration: 600/3125, Loss: 1.67
# Iteration: 700/3125, Loss: 1.68
# Iteration: 800/3125, Loss: 1.96
# Iteration: 900/3125, Loss: 1.27
# Iteration: 1000/3125, Loss: 2.51
# Iteration: 1100/3125, Loss: 2.11
# Iteration: 1200/3125, Loss: 1.62
# Iteration: 1300/3125, Loss: 2.17
# Iteration: 1400/3125, Loss: 1.98
# Iteration: 1500/3125, Loss: 2.74
# Iteration: 1600/3125, Loss: 2.27
# Iteration: 1700/3125, Loss: 1.62
# Iteration: 1800/3125, Loss: 1.89
# Iteration: 1900/3125, Loss: 2.25
# Iteration: 2000/3125, Loss: 2.23
# Iteration: 2100/3125, Loss: 1.20
# Iteration: 2200/3125, Loss: 1.70
# Iteration: 2300/3125, Loss: 1.81
# Iteration: 2400/3125, Loss: 1.46
# Iteration: 2500/3125, Loss: 2.57
# Iteration: 2600/3125, Loss: 2.49
# Iteration: 2700/3125, Loss: 1.94
# Iteration: 2800/3125, Loss: 2.24
# Epoch [9/20], Training Loss: 2.3197, Validation Loss: 2.3213, Train Acc: 0.3780, Val Acc: 0.3816
# Iteration: 0/3125, Loss: 2.97
# Iteration: 100/3125, Loss: 2.35
# Iteration: 200/3125, Loss: 2.30
# Iteration: 300/3125, Loss: 1.76
# Iteration: 400/3125, Loss: 1.94
# Iteration: 500/3125, Loss: 1.62
# Iteration: 600/3125, Loss: 2.23
# Iteration: 700/3125, Loss: 2.91
# Iteration: 800/3125, Loss: 2.89
# Iteration: 900/3125, Loss: 2.28
# Iteration: 1000/3125, Loss: 1.52
# Iteration: 1100/3125, Loss: 2.65
# Iteration: 1200/3125, Loss: 1.27
# Iteration: 1300/3125, Loss: 2.54
# Iteration: 1400/3125, Loss: 3.30
# Iteration: 1500/3125, Loss: 2.58
# Iteration: 1600/3125, Loss: 2.22
# Iteration: 1700/3125, Loss: 1.92
# Iteration: 1800/3125, Loss: 1.60
# Iteration: 1900/3125, Loss: 2.23
# Iteration: 2000/3125, Loss: 2.29
# Iteration: 2100/3125, Loss: 2.73
# Iteration: 2200/3125, Loss: 2.50
# Iteration: 2300/3125, Loss: 2.49
# Iteration: 2400/3125, Loss: 2.28
# Iteration: 2500/3125, Loss: 1.95
# Iteration: 2600/3125, Loss: 1.95
# Iteration: 2700/3125, Loss: 3.00
# Iteration: 2800/3125, Loss: 2.02
# Epoch [10/20], Training Loss: 2.3307, Validation Loss: 2.3657, Train Acc: 0.3791, Val Acc: 0.3712
# Iteration: 0/3125, Loss: 1.43
# Iteration: 100/3125, Loss: 1.55
# Iteration: 200/3125, Loss: 2.40
# Iteration: 300/3125, Loss: 3.01
# Iteration: 400/3125, Loss: 1.82
# Iteration: 500/3125, Loss: 1.46
# Iteration: 600/3125, Loss: 1.34
# Iteration: 700/3125, Loss: 2.27
# Iteration: 800/3125, Loss: 2.60
# Iteration: 900/3125, Loss: 3.58
# Iteration: 1000/3125, Loss: 2.36
# Iteration: 1100/3125, Loss: 2.21
# Iteration: 1200/3125, Loss: 1.89
# Iteration: 1300/3125, Loss: 1.18
# Iteration: 1400/3125, Loss: 2.77
# Iteration: 1500/3125, Loss: 2.23
# Iteration: 1600/3125, Loss: 2.55
# Iteration: 1700/3125, Loss: 2.39
# Iteration: 1800/3125, Loss: 1.77
# Iteration: 1900/3125, Loss: 2.86
# Iteration: 2000/3125, Loss: 2.94
# Iteration: 2100/3125, Loss: 2.70
# Iteration: 2200/3125, Loss: 3.23
# Iteration: 2300/3125, Loss: 1.83
# Iteration: 2400/3125, Loss: 2.97
# Iteration: 2500/3125, Loss: 2.11
# Iteration: 2600/3125, Loss: 1.65
# Iteration: 2700/3125, Loss: 3.89
# Iteration: 2800/3125, Loss: 3.41
# Epoch [11/20], Training Loss: 2.3261, Validation Loss: 2.3563, Train Acc: 0.3863, Val Acc: 0.3794
# Iteration: 0/3125, Loss: 2.79
# Iteration: 100/3125, Loss: 2.15
# Iteration: 200/3125, Loss: 3.50
# Iteration: 300/3125, Loss: 2.99
# Iteration: 400/3125, Loss: 2.05
# Iteration: 500/3125, Loss: 2.35
# Iteration: 600/3125, Loss: 1.79
# Iteration: 700/3125, Loss: 1.80
# Iteration: 800/3125, Loss: 2.00
# Iteration: 900/3125, Loss: 2.46
# Iteration: 1000/3125, Loss: 2.76
# Iteration: 1100/3125, Loss: 2.45
# Iteration: 1200/3125, Loss: 2.12
# Iteration: 1300/3125, Loss: 1.92
# Iteration: 1400/3125, Loss: 2.00
# Iteration: 1500/3125, Loss: 1.57
# Iteration: 1600/3125, Loss: 2.52
# Iteration: 1700/3125, Loss: 2.50
# Iteration: 1800/3125, Loss: 2.71
# Iteration: 1900/3125, Loss: 2.21
# Iteration: 2000/3125, Loss: 3.49
# Iteration: 2100/3125, Loss: 1.59
# Iteration: 2200/3125, Loss: 1.57
# Iteration: 2300/3125, Loss: 2.17
# Iteration: 2400/3125, Loss: 2.24
# Iteration: 2500/3125, Loss: 1.60
# Iteration: 2600/3125, Loss: 1.91
# Iteration: 2700/3125, Loss: 3.08
# Iteration: 2800/3125, Loss: 2.30
# Epoch [12/20], Training Loss: 2.3226, Validation Loss: 2.3121, Train Acc: 0.3680, Val Acc: 0.3536
# Iteration: 0/3125, Loss: 2.45
# Iteration: 100/3125, Loss: 1.81
# Iteration: 200/3125, Loss: 1.70
# Iteration: 300/3125, Loss: 2.24
# Iteration: 400/3125, Loss: 1.93
# Iteration: 500/3125, Loss: 2.37
# Iteration: 600/3125, Loss: 2.47
# Iteration: 700/3125, Loss: 2.78
# Iteration: 800/3125, Loss: 2.96
# Iteration: 900/3125, Loss: 1.40
# Iteration: 1000/3125, Loss: 2.44
# Iteration: 1100/3125, Loss: 2.11
# Iteration: 1200/3125, Loss: 2.53
# Iteration: 1300/3125, Loss: 2.07
# Iteration: 1400/3125, Loss: 1.99
# Iteration: 1500/3125, Loss: 2.66
# Iteration: 1600/3125, Loss: 2.33
# Iteration: 1700/3125, Loss: 1.27
# Iteration: 1800/3125, Loss: 2.20
# Iteration: 1900/3125, Loss: 1.91
# Iteration: 2000/3125, Loss: 2.16
# Iteration: 2100/3125, Loss: 1.53
# Iteration: 2200/3125, Loss: 2.80
# Iteration: 2300/3125, Loss: 2.37
# Iteration: 2400/3125, Loss: 1.74
# Iteration: 2500/3125, Loss: 2.23
# Iteration: 2600/3125, Loss: 2.05
# Iteration: 2700/3125, Loss: 2.06
# Iteration: 2800/3125, Loss: 2.30
# Epoch [13/20], Training Loss: 2.3126, Validation Loss: 2.3206, Train Acc: 0.3856, Val Acc: 0.3830
# Iteration: 0/3125, Loss: 1.67
# Iteration: 100/3125, Loss: 2.27
# Iteration: 200/3125, Loss: 3.01
# Iteration: 300/3125, Loss: 2.19
# Iteration: 400/3125, Loss: 1.63
# Iteration: 500/3125, Loss: 2.70
# Iteration: 600/3125, Loss: 3.76
# Iteration: 700/3125, Loss: 2.24
# Iteration: 800/3125, Loss: 1.41
# Iteration: 900/3125, Loss: 2.53
# Iteration: 1000/3125, Loss: 1.45
# Iteration: 1100/3125, Loss: 1.79
# Iteration: 1200/3125, Loss: 2.86
# Iteration: 1300/3125, Loss: 3.48
# Iteration: 1400/3125, Loss: 1.76
# Iteration: 1500/3125, Loss: 2.66
# Iteration: 1600/3125, Loss: 2.45
# Iteration: 1700/3125, Loss: 4.09
# Iteration: 1800/3125, Loss: 2.35
# Iteration: 1900/3125, Loss: 3.08
# Iteration: 2000/3125, Loss: 1.73
# Iteration: 2100/3125, Loss: 2.28
# Iteration: 2200/3125, Loss: 2.85
# Iteration: 2300/3125, Loss: 2.20
# Iteration: 2400/3125, Loss: 3.88
# Iteration: 2500/3125, Loss: 2.87
# Iteration: 2600/3125, Loss: 3.06
# Iteration: 2700/3125, Loss: 2.07
# Iteration: 2800/3125, Loss: 3.99
# Epoch [14/20], Training Loss: 2.3151, Validation Loss: 2.3619, Train Acc: 0.3812, Val Acc: 0.3852
# Iteration: 0/3125, Loss: 2.28
# Iteration: 100/3125, Loss: 2.57
# Iteration: 200/3125, Loss: 2.82
# Iteration: 300/3125, Loss: 2.29
# Iteration: 400/3125, Loss: 1.62
# Iteration: 500/3125, Loss: 2.16
# Iteration: 600/3125, Loss: 2.17
# Iteration: 700/3125, Loss: 2.37
# Iteration: 800/3125, Loss: 2.87
# Iteration: 900/3125, Loss: 2.74
# Iteration: 1000/3125, Loss: 1.67
# Iteration: 1100/3125, Loss: 3.50
# Iteration: 1200/3125, Loss: 1.59
# Iteration: 1300/3125, Loss: 2.04
# Iteration: 1400/3125, Loss: 2.79
# Iteration: 1500/3125, Loss: 2.59
# Iteration: 1600/3125, Loss: 3.06
# Iteration: 1700/3125, Loss: 2.56
# Iteration: 1800/3125, Loss: 2.47
# Iteration: 1900/3125, Loss: 1.96
# Iteration: 2000/3125, Loss: 1.35
# Iteration: 2100/3125, Loss: 3.32
# Iteration: 2200/3125, Loss: 2.49
# Iteration: 2300/3125, Loss: 1.73
# Iteration: 2400/3125, Loss: 1.91
# Iteration: 2500/3125, Loss: 1.77
# Iteration: 2600/3125, Loss: 2.83
# Iteration: 2700/3125, Loss: 2.68
# Iteration: 2800/3125, Loss: 3.01
# Epoch [15/20], Training Loss: 2.3255, Validation Loss: 2.3339, Train Acc: 0.3793, Val Acc: 0.3688
# Iteration: 0/3125, Loss: 2.75
# Iteration: 100/3125, Loss: 2.61
# Iteration: 200/3125, Loss: 2.28
# Iteration: 300/3125, Loss: 2.53
# Iteration: 400/3125, Loss: 1.81
# Iteration: 500/3125, Loss: 2.66
# Iteration: 600/3125, Loss: 1.75
# Iteration: 700/3125, Loss: 2.59
# Iteration: 800/3125, Loss: 1.82
# Iteration: 900/3125, Loss: 2.29
# Iteration: 1000/3125, Loss: 1.14
# Iteration: 1100/3125, Loss: 1.74
# Iteration: 1200/3125, Loss: 1.53
# Iteration: 1300/3125, Loss: 1.65
# Iteration: 1400/3125, Loss: 2.77
# Iteration: 1500/3125, Loss: 2.69
# Iteration: 1600/3125, Loss: 1.68
# Iteration: 1700/3125, Loss: 2.39
# Iteration: 1800/3125, Loss: 2.69
# Iteration: 1900/3125, Loss: 1.35
# Iteration: 2000/3125, Loss: 1.93
# Iteration: 2100/3125, Loss: 2.01
# Iteration: 2200/3125, Loss: 1.76
# Iteration: 2300/3125, Loss: 2.25
# Iteration: 2400/3125, Loss: 3.78
# Iteration: 2500/3125, Loss: 2.75
# Iteration: 2600/3125, Loss: 1.66
# Iteration: 2700/3125, Loss: 2.39
# Iteration: 2800/3125, Loss: 2.48
# Epoch [16/20], Training Loss: 2.3326, Validation Loss: 2.4244, Train Acc: 0.3730, Val Acc: 0.3634
# Iteration: 0/3125, Loss: 2.59
# Iteration: 100/3125, Loss: 2.08
# Iteration: 200/3125, Loss: 1.76
# Iteration: 300/3125, Loss: 1.70
# Iteration: 400/3125, Loss: 2.00
# Iteration: 500/3125, Loss: 1.06
# Iteration: 600/3125, Loss: 1.90
# Iteration: 700/3125, Loss: 2.43
# Iteration: 800/3125, Loss: 3.19
# Iteration: 900/3125, Loss: 1.46
# Iteration: 1000/3125, Loss: 2.60
# Iteration: 1100/3125, Loss: 2.41
# Iteration: 1200/3125, Loss: 2.14
# Iteration: 1300/3125, Loss: 1.86
# Iteration: 1400/3125, Loss: 2.67
# Iteration: 1500/3125, Loss: 1.73
# Iteration: 1600/3125, Loss: 2.18
# Iteration: 1700/3125, Loss: 3.05
# Iteration: 1800/3125, Loss: 2.73
# Iteration: 1900/3125, Loss: 2.13
# Iteration: 2000/3125, Loss: 2.80
# Iteration: 2100/3125, Loss: 1.89
# Iteration: 2200/3125, Loss: 2.09
# Iteration: 2300/3125, Loss: 2.51
# Iteration: 2400/3125, Loss: 2.71
# Iteration: 2500/3125, Loss: 2.34
# Iteration: 2600/3125, Loss: 2.46
# Iteration: 2700/3125, Loss: 2.63
# Iteration: 2800/3125, Loss: 1.65
# Epoch [17/20], Training Loss: 2.3283, Validation Loss: 2.3815, Train Acc: 0.3984, Val Acc: 0.3752
# Iteration: 0/3125, Loss: 2.65
# Iteration: 100/3125, Loss: 2.04
# Iteration: 200/3125, Loss: 2.74
# Iteration: 300/3125, Loss: 2.68
# Iteration: 400/3125, Loss: 2.16
# Iteration: 500/3125, Loss: 2.36
# Iteration: 600/3125, Loss: 1.52
# Iteration: 700/3125, Loss: 2.42
# Iteration: 800/3125, Loss: 2.23
# Iteration: 900/3125, Loss: 2.57
# Iteration: 1000/3125, Loss: 2.08
# Iteration: 1100/3125, Loss: 2.39
# Iteration: 1200/3125, Loss: 1.75
# Iteration: 1300/3125, Loss: 3.17
# Iteration: 1400/3125, Loss: 3.53
# Iteration: 1500/3125, Loss: 2.57
# Iteration: 1600/3125, Loss: 2.44
# Iteration: 1700/3125, Loss: 2.62
# Iteration: 1800/3125, Loss: 3.03
# Iteration: 1900/3125, Loss: 2.98
# Iteration: 2000/3125, Loss: 2.91
# Iteration: 2100/3125, Loss: 2.08
# Iteration: 2200/3125, Loss: 1.91
# Iteration: 2300/3125, Loss: 2.96
# Iteration: 2400/3125, Loss: 2.29
# Iteration: 2500/3125, Loss: 1.94
# Iteration: 2600/3125, Loss: 1.41
# Iteration: 2700/3125, Loss: 1.92
# Iteration: 2800/3125, Loss: 1.88
# Epoch [18/20], Training Loss: 2.3167, Validation Loss: 2.3965, Train Acc: 0.3750, Val Acc: 0.3668
# Iteration: 0/3125, Loss: 2.57
# Iteration: 100/3125, Loss: 2.87
# Iteration: 200/3125, Loss: 3.63
# Iteration: 300/3125, Loss: 1.94
# Iteration: 400/3125, Loss: 1.91
# Iteration: 500/3125, Loss: 2.04
# Iteration: 600/3125, Loss: 2.81
# Iteration: 700/3125, Loss: 2.59
# Iteration: 800/3125, Loss: 2.33
# Iteration: 900/3125, Loss: 2.99
# Iteration: 1000/3125, Loss: 2.52
# Iteration: 1100/3125, Loss: 1.00
# Iteration: 1200/3125, Loss: 2.39
# Iteration: 1300/3125, Loss: 2.39
# Iteration: 1400/3125, Loss: 2.23
# Iteration: 1500/3125, Loss: 1.89
# Iteration: 1600/3125, Loss: 1.64
# Iteration: 1700/3125, Loss: 3.03
# Iteration: 1800/3125, Loss: 2.47
# Iteration: 1900/3125, Loss: 2.41
# Iteration: 2000/3125, Loss: 2.48
# Iteration: 2100/3125, Loss: 3.35
# Iteration: 2200/3125, Loss: 2.61
# Iteration: 2300/3125, Loss: 1.93
# Iteration: 2400/3125, Loss: 1.31
# Iteration: 2500/3125, Loss: 2.23
# Iteration: 2600/3125, Loss: 2.67
# Iteration: 2700/3125, Loss: 1.28
# Iteration: 2800/3125, Loss: 1.76
# Epoch [19/20], Training Loss: 2.3276, Validation Loss: 2.3804, Train Acc: 0.3732, Val Acc: 0.3736
# Iteration: 0/3125, Loss: 2.87
# Iteration: 100/3125, Loss: 2.07
# Iteration: 200/3125, Loss: 2.22
# Iteration: 300/3125, Loss: 1.28
# Iteration: 400/3125, Loss: 2.14
# Iteration: 500/3125, Loss: 3.06
# Iteration: 600/3125, Loss: 3.28
# Iteration: 700/3125, Loss: 2.47
# Iteration: 800/3125, Loss: 2.50
# Iteration: 900/3125, Loss: 2.33
# Iteration: 1000/3125, Loss: 1.73
# Iteration: 1100/3125, Loss: 2.06
# Iteration: 1200/3125, Loss: 1.43
# Iteration: 1300/3125, Loss: 2.05
# Iteration: 1400/3125, Loss: 2.36
# Iteration: 1500/3125, Loss: 2.17
# Iteration: 1600/3125, Loss: 2.15
# Iteration: 1700/3125, Loss: 3.00
# Iteration: 1800/3125, Loss: 2.36
# Iteration: 1900/3125, Loss: 2.33
# Iteration: 2000/3125, Loss: 1.27
# Iteration: 2100/3125, Loss: 2.03
# Iteration: 2200/3125, Loss: 3.62
# Iteration: 2300/3125, Loss: 2.94
# Iteration: 2400/3125, Loss: 3.20
# Iteration: 2500/3125, Loss: 2.90
# Iteration: 2600/3125, Loss: 1.65
# Iteration: 2700/3125, Loss: 2.07
# Iteration: 2800/3125, Loss: 3.63
# Epoch [20/20], Training Loss: 2.3191, Validation Loss: 2.3174, Train Acc: 0.3873, Val Acc: 0.3782

# %%
plt.plot(loss_epoch_arr)
plt.show()

# %%
vgg.load_state_dict(best_model)
print(evaluation(trainloader, vgg), evaluation(testloader, vgg))
# Out:
# 0.391 0.3771

# %%
# Plot loss curves
plt.plot(range(1, max_epochs+1), train_loss_arr, label='Training Loss')
plt.plot(range(1, max_epochs+1), val_loss_arr, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss Over Epochs')
plt.show()
